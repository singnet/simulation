# %% [markdown]
# # Baseline for the Competing Clusterers Scenario
#
# This notebook produces a spreadsheet, InternetResearchAgency_tweets.clustered.csv .  It takes an existing csv of tweets and adds columns for 12 clustering algorithms from skikit learn and NLTK.  For each algorithm, one column is added that has that algorithms clustering assignment, and another one shows the closeness of the tweet to the centroid of the cluster.  This similarity  is in the vector space that is made be the gensim neural network doc2vec algorithm.  Sorting the notebook on cluster than similarity from the centroid gives an impression of the quality of the cluster, those tweets closest to the centroid being the most representative of the cluster.
#
#
# The notebook is useful for a baseline for the competing clusterers scenario of the Singularity Net Simulation.  The user can run the data through this notebook to see how the clusterers might normally perform, so as to have a context by which to judge the quality of the solutions that the simulation agents have created.

# %%
#parameters
input_root = 'data/tweets'
output_root = 'InternetResearchAgency'

# %%
import numpy as np
import pandas as pd
raw_data_path = input_root + '.csv'
raw_data_path_clustered =  input_root + '_' + output_root + '.clustered.csv'

#raw_data = pd.read_csv(raw_data_path, encoding = "utf-8")
raw_data = pd.read_csv(raw_data_path, encoding = "ISO-8859-1")
print('Number of instances: ' + str(len(raw_data)))
# Out:
# Number of instances: 203451

# %%
raw_data.head()
# Out:
#         user_id         user_key    created_at          created_str  \
# 0  2.532612e+09        kathiemrr  1.488207e+12  2017-02-27 14:54:00
# 1  2.531160e+09   traceyhappymom  1.471273e+12  2016-08-15 14:50:20
# 2           NaN    evewebster373  1.435701e+12  2015-06-30 21:56:09
# 3  4.840552e+09      blacktolive  1.474013e+12  2016-09-16 08:04:48
# 4  1.694026e+09  jacquelinisbest  1.474228e+12  2016-09-18 19:46:25
#
#    retweet_count retweeted  favorite_count  \
# 0            NaN       NaN             NaN
# 1            NaN       NaN             NaN
# 2            NaN       NaN             NaN
# 3           18.0     False            17.0
# 4            0.0     False             0.0
#
#                                                                                                                                                 text  \
# 0                                                                                                    #ThingsDoneByMistake kissing auntie in the lips
# 1                                                                  RT @mc_derpin: #TheOlderWeGet the more pessimistic we are https://t.co/zS3jHZJl8P
# 2                      RT @dmataconis: Ready To Feel Like A Failure? Joan Of Arc Was Only 19 When She Was Burned At The Stake http://t.co/S2j1IFm4y9
# 3                                                                                                    Amen! #blacklivesmatter https://t.co/wGffaOqgzl
# 4  RT @NahBabyNah: Twitchy: Chuck Todd caught out there shilling for Hillary Clinton\r\nThe post BUSTED: Adam Baldwi... https://t.co/ay28pMpDw6 #â¦
#
#        tweet_id  \
# 0  8.362279e+17
# 1  7.651989e+17
# 2  6.160023e+17
# 3  7.766933e+17
# 4  7.775946e+17
#
#                                                                source  \
# 0                                                                 NaN
# 1                                                                 NaN
# 2                                                                 NaN
# 3  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# 4  <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
#
#                   hashtags                                expanded_urls  \
# 0  ["ThingsDoneByMistake"]                                           []
# 1        ["TheOlderWeGet"]                                           []
# 2                       []                                           []
# 3     ["Blacklivesmatter"]                                           []
# 4        ["WakeUpAmerica"]  ["http://ln.is/twitchy.com/loriz-31/3yafU"]
#
#    posted        mentions  retweeted_status_id  in_reply_to_status_id
# 0  POSTED              []                  NaN                    NaN
# 1  POSTED              []                  NaN                    NaN
# 2  POSTED              []                  NaN                    NaN
# 3  POSTED              []                  NaN                    NaN
# 4  POSTED  ["nahbabynah"]         7.775915e+17                    NaN

# %%
import gensim
import re


def createTrainingSet(data, raw_data_path):
    #create the training set and add a unique id to the output file for each comment
    data['SingularityNetID'] = -1
    doc2VecTrain = []
    with open('stopwords.txt','r') as f:
        stopwords = {word.lower().strip() for word in f.readlines()}
    for i in range (len(data)):
        if data.loc[i,'text']:
            comment = data.loc[i,'text']
            try:
                comment = re.sub(r"\s?http\S*", "", comment)
            except:
                pass
            #strList =gensim.utils.simple_preprocess(str(comment))
            tokenList =gensim.utils.lemmatize(str(comment),stopwords=frozenset(stopwords))
            strList =[x.decode('utf-8') for x in tokenList]
            if strList:
                data.loc[i, "SingularityNetID"] = i
                taggedDoc = gensim.models.doc2vec.TaggedDocument(strList,[i])
                doc2VecTrain.append(taggedDoc)
                
    data.to_csv(raw_data_path_clustered)
    import random
    # %time random.shuffle(doc2VecTrain)
    print (len(doc2VecTrain))
    for i in range(10):
        print (doc2VecTrain[i])
    #debug = open ("debug.txt","w")
    #debug.write(str(doc2VecTrain))  
    #debug.close()

    return(doc2VecTrain)

# %%
import pickle
from pathlib import Path

doc2Vec_pickle = output_root + "_doc2VecTrain.p"
my_file = Path(output_root + doc2Vec_pickle)
if my_file.exists():
    # %time doc2VecTrain = pickle.load ( open (doc2Vec_pickle, "rb"))
else:
    # %time doc2VecTrain = createTrainingSet(raw_data, raw_data_path)
    pickle.dump (doc2VecTrain, open (doc2Vec_pickle, "wb"))
# Out:
# CPU times: user 128 ms, sys: 0 ns, total: 128 ms
# Wall time: 129 ms
# 202778
# TaggedDocument(['rt/NN', 'orconservative/JJ', 'gregjkrieg/NN', 'obama/NN', 'christian/JJ', 'follow/VB', 'bible/JJ', 'everyone/NN', 'else/RB', 'read/VB'], [77062])
# TaggedDocument(['livin/NN', 'easy/JJ', 'smart/JJ'], [179052])
# TaggedDocument(['rt/NN', 'financement/NN', 'du/NN', 'fn/NN', 'de/JJ', 'saint/NN', 'just/RB', 'va/JJ', 'porter/NN', 'plainte/NN', 'contre/JJ', 'etat/NN'], [30478])
# TaggedDocument(['obama/JJ', 'administration/NN', 'confirm/VB', 'double/JJ', 'digit/NN', 'insurance/NN', 'premium/NN', 'hike/NN'], [21384])
# TaggedDocument(['liberal/NN', 'least/JJ', 'tran/NN', 'youth/NN', 'die/VB', 'suicide/NN', 'trumpâ/NN', 'win/VB', 'none/NN', 'report/VB', 'death/NN', 'confirmedâ/VB'], [81591])
# TaggedDocument(['rt/NN', 'jc/NN', 'nothing/NN'], [91807])
# TaggedDocument(['sharium/NN', 'law/NN', 'ban/VB', 'united/NN', 'states/NN', 'sheriff/NN', 'david/VB', 'clarke/NN'], [72158])
# TaggedDocument(['merkel/NN', 'verstehet/NN', 'es/NN', 'dass/NN', 'es/NN', 'gezielte/NN', 'neubau/JJ', 'von/NN', 'straã/NN', 'en/NN', 'nã/NN', 'tig/NN', 'sei/NN'], [6477])
# TaggedDocument(['rt/NN', 'chiefkeef/NN', 'speak/VB'], [126694])
# TaggedDocument(['rt/NN', 'ggle/VB', 'la/VB', 'deadline/NN', 'register/VB', 'tomorrow/NN', 'feb/NN', 'feelthebern/NN'], [76808])
# CPU times: user 19min 11s, sys: 2min 38s, total: 21min 50s
# Wall time: 21min 53s

# %%
from pathlib import Path
modelPath = './' + output_root + '_facism_model'
size = 200
min_count = 5
totalIters = 1000

if Path(modelPath).is_file():
    model = gensim.models.doc2vec.Doc2Vec.load(modelPath)
else:
    model = gensim.models.doc2vec.Doc2Vec(size=size, min_count=min_count, iter=totalIters, dm=0)
    model.build_vocab(doc2VecTrain)
    print (model.corpus_count)
    print (model.iter)
    # %time model.train(doc2VecTrain, total_examples=model.corpus_count, epochs=model.iter)
    model.delete_temporary_training_data(keep_doctags_vectors=True, keep_inference=True)
    model.save(modelPath)
    model = gensim.models.doc2vec.Doc2Vec.load(modelPath)

# %%
print("len(model.wv.vocab)")
print(str(len(model.wv.vocab)))
# Out:
# len(model.wv.vocab)
# 27163

# %% [markdown]
# ## Test the Semantic Space
# In order to test the quality of the semantic space created by Doc2Vec, the following two cells may be run in sequence multiple times.  The first cell picks a random comment, and the second cell finds the five comments across the space that are the most similar.  A comment appearing as most similar to itself is a sign of a high quality semantic space.

# %%
import random

randindex = random.randint(0,len (doc2VecTrain))
print(randindex)
realIndex = doc2VecTrain[randindex][1][0]
print("index:" + str(realIndex))
print (doc2VecTrain[randindex][0])
themeVector = model.infer_vector(doc2VecTrain[randindex][0])
mostSim =  model.docvecs.most_similar([themeVector], topn=5)
print(themeVector)
# Out:
# 29209
# index:4561
# ['bernie/NN', 'ready/JJ', 'invite/VB', 'many/JJ', 'refugee/NN', 'sufficient/JJ', 'make/VB', 'president/NN', 'demdebatemiami/NN']
# [ 0.1944351  -0.03905831  0.02347476 -0.03977409  0.09997911 -0.05085656
#  -0.0557252   0.14759946 -0.5069165   0.17577572  0.135265    0.283784
#  -0.15946224 -0.15062726 -0.14205624 -0.3112278   0.16221574 -0.3910323
#   0.13420735  0.41706243 -0.3207433   0.0245885   0.10386068 -0.19277473
#  -0.3574071  -0.20579587 -0.15555997 -0.17086482  0.08112323 -0.10985532
#  -0.21693078  0.03936861  0.00165979  0.03749555  0.16271776  0.18455416
#   0.05773365 -0.2956466  -0.14464307 -0.32535958  0.05686299  0.0686315
#  -0.03857032 -0.01076763  0.4270765   0.23020366  0.11758833 -0.22938876
#  -0.3263684  -0.2894638   0.02797775 -0.08155999 -0.167802    0.25930944
#   0.10285083  0.38919833  0.24527839  0.04784041  0.07479761 -0.24977522
#   0.36882174 -0.37429723 -0.20537248  0.00811404 -0.16692631 -0.17888643
#  -0.33774918 -0.18723671  0.12338962 -0.24120092  0.37789863  0.13133182
#  -0.18752049 -0.12416267 -0.06887268 -0.30349058  0.21729457  0.01636423
#   0.08281523 -0.06282315  0.17041288 -0.1633603   0.17860629  0.11696649
#   0.07860211 -0.16516566  0.01885861  0.1491183   0.41652852  0.2335207
#   0.00851734 -0.38629836 -0.17319022 -0.18056646  0.2232803   0.19170476
#   0.2924145   0.08120002 -0.01949978  0.22212921  0.07142414  0.04699961
#  -0.24291882 -0.1315861   0.1202495   0.07737589 -0.07854322  0.18900216
#  -0.08219394 -0.02677125  0.33796763 -0.05089961 -0.17245016  0.22180454
#  -0.00150568 -0.13772431 -0.2131495   0.21496812 -0.14087601  0.08888152
#   0.19264936 -0.16776961  0.08254902 -0.01266355  0.0943687   0.24065441
#   0.05176166 -0.2322887  -0.00209557 -0.0868934   0.1274402  -0.21142475
#  -0.17533037  0.06062697 -0.33419347  0.21243085  0.05649988  0.11799666
#   0.03833935  0.14792182  0.60105306  0.2497885   0.16909397  0.07653248
#   0.0510033  -0.10495889 -0.49467626  0.1354951  -0.23483579  0.1950969
#  -0.24040794 -0.14024343  0.15298697 -0.36194032  0.05987706  0.19946232
#  -0.06581385 -0.02753147 -0.11171426  0.15702328 -0.09277792  0.22999248
#   0.2145482   0.1136126  -0.12658337 -0.1589326   0.01846737 -0.38033903
#  -0.19919878 -0.15822323  0.23373319 -0.23848948 -0.06205847  0.16614483
#   0.1393021  -0.16689683 -0.15139386 -0.08348044  0.02854148 -0.11896113
#   0.20768782 -0.06301346  0.02493425  0.30094743 -0.2034651  -0.13611066
#  -0.04584941 -0.2631372  -0.27855697  0.28184584  0.13358334  0.25617793
#  -0.01533245  0.08519587 -0.05948182  0.05989303 -0.52468294 -0.00951713
#  -0.0638285  -0.27513316]

# %%
pd.options.display.max_colwidth = 10000
mostSim =  model.docvecs.most_similar([themeVector], topn=5)

v1 = model.docvecs[realIndex].reshape(size,)
v2s = []
for id,dist in mostSim[:5]:
    print ("index:" + str(id))
    print ('similarity: ' + str(dist))
    justsim = model.docvecs.similarity(realIndex,id)
    print ('just_similarity: ' + str(justsim))
    comment = raw_data.loc[id]['text']
    v2s.append(model.docvecs[id])
    print(comment)
print ('v1')
print (v1)
print ('np.shape(v1)')
print (np.shape(v1))
print ('v2s')
print (v2s)
print ('np.shape(v2s)')
print (np.shape(v2s))
vsim = model.wv.cosine_similarities(v1,v2s)
print ('vsim')
print (vsim)
print ('np.shape(vsim)')
print (np.shape(vsim))
#print (model.docvecs[id])
# Out:
# index:4561
# similarity: 0.8208450078964233
# just_similarity: 1.0
# Bernie is ready to invite as many refugees as it would be sufficient to make him the president #DemDebateMiami
# index:59611
# similarity: 0.5527162551879883
# just_similarity: 0.6269402504467396
# Bernie Sanders: letâs make America socialist again #DemDebate #DemDebateMiami
# index:159664
# similarity: 0.5360962748527527
# just_similarity: 0.5738347131573727
# Are you ready?
# index:79112
# similarity: 0.535906195640564
# just_similarity: 0.6332480444032913
# They both are too old to be our president #DemDebateMiami
# index:114610
# similarity: 0.5307534337043762
# just_similarity: 0.573454870361426
# âI`m ready for selfieâ #WhatClintonWrites
# v1
# [ 0.32570013 -0.09336285  0.2437899  -0.33785182  0.24543191 -0.06085902
#   0.15546627  0.10887211 -0.691765    0.2954488   0.02804246  0.43864205
#  -0.12526427 -0.00530394 -0.22727738 -0.44537798  0.23981842 -0.4353826
#  -0.19952579  0.5622258  -0.25527537 -0.10378052 -0.09796141  0.03189933
#  -0.49690706 -0.34843993 -0.06808036 -0.40254205  0.21724023 -0.26393953
#  -0.47999078  0.15228419 -0.16885245  0.18472062  0.3172518   0.46904355
#   0.3699973  -0.26349574 -0.23308796 -0.509679   -0.2457238  -0.11220298
#   0.05248426 -0.08161312  0.56794304  0.27215207 -0.07123614 -0.4229476
#  -0.38680208 -0.4182788  -0.08923052 -0.00388886 -0.05002259  0.16102147
#   0.29171222  0.7346673   0.34981942 -0.34679618  0.15160367 -0.3119554
#   0.56335986 -0.51396143 -0.09585363  0.23629197  0.3025914  -0.37092265
#  -0.48935607 -0.26867172  0.39148512 -0.28514227  0.5986526   0.00879442
#  -0.13260819 -0.11616805  0.26575044 -0.6913884   0.03160324 -0.03483037
#   0.26179546  0.04334953  0.3269899  -0.23191999  0.12312329  0.26022613
#  -0.12728322 -0.26218402 -0.05089607  0.34069896  0.66453797  0.3158131
#  -0.30280465 -0.00235894 -0.36971506 -0.28727242  0.2596369   0.22911115
#   0.38084638  0.04658465  0.19430815 -0.11982727  0.21043025  0.07248677
#  -0.5260407  -0.09633017  0.28938264  0.0952811  -0.00512148  0.2792129
#  -0.29928988 -0.088538    0.29585886  0.02992295 -0.24747424  0.382373
#   0.2611176   0.07357042 -0.4420213   0.18302022 -0.14569338  0.2085724
#   0.14325866 -0.12686573 -0.03187249  0.02157154 -0.02989702  0.15716434
#   0.36524075  0.00644294 -0.05562984 -0.2737926   0.01491096 -0.50998104
#  -0.27638283  0.2676999  -0.6632062   0.31054196  0.29704332  0.39025384
#  -0.01239664  0.30115393  0.9830213   0.5308705   0.37877938  0.07688212
#   0.35519612 -0.09879415 -0.80299664  0.2911422  -0.14649299  0.42108843
#  -0.15167132  0.03755539 -0.06773882 -0.24118474  0.10316206  0.06192245
#   0.157882   -0.19918592 -0.3295163   0.06120074  0.00255274  0.45719385
#   0.42983243 -0.10501    -0.18893568 -0.48905066 -0.38970056 -0.80354315
#  -0.26624534 -0.05874904  0.47505555 -0.46065754 -0.3419014   0.0743309
#  -0.00929593  0.18787804 -0.17563558 -0.24616113  0.06530389 -0.5670311
#   0.6603398   0.08906521  0.01354342  0.40171614 -0.37732005 -0.11934616
#  -0.01070264 -0.12332488 -0.3717427   0.4930208   0.29596856 -0.207768
#  -0.31914905  0.13975005  0.03193976  0.04297966 -0.5930915  -0.26201797
#  -0.37621367 -0.17550088]
# np.shape(v1)
# (200,)
# v2s
# [array([ 0.32570013, -0.09336285,  0.2437899 , -0.33785182,  0.24543191,
#        -0.06085902,  0.15546627,  0.10887211, -0.691765  ,  0.2954488 ,
#         0.02804246,  0.43864205, -0.12526427, -0.00530394, -0.22727738,
#        -0.44537798,  0.23981842, -0.4353826 , -0.19952579,  0.5622258 ,
#        -0.25527537, -0.10378052, -0.09796141,  0.03189933, -0.49690706,
#        -0.34843993, -0.06808036, -0.40254205,  0.21724023, -0.26393953,
#        -0.47999078,  0.15228419, -0.16885245,  0.18472062,  0.3172518 ,
#         0.46904355,  0.3699973 , -0.26349574, -0.23308796, -0.509679  ,
#        -0.2457238 , -0.11220298,  0.05248426, -0.08161312,  0.56794304,
#         0.27215207, -0.07123614, -0.4229476 , -0.38680208, -0.4182788 ,
#        -0.08923052, -0.00388886, -0.05002259,  0.16102147,  0.29171222,
#         0.7346673 ,  0.34981942, -0.34679618,  0.15160367, -0.3119554 ,
#         0.56335986, -0.51396143, -0.09585363,  0.23629197,  0.3025914 ,
#        -0.37092265, -0.48935607, -0.26867172,  0.39148512, -0.28514227,
#         0.5986526 ,  0.00879442, -0.13260819, -0.11616805,  0.26575044,
#        -0.6913884 ,  0.03160324, -0.03483037,  0.26179546,  0.04334953,
#         0.3269899 , -0.23191999,  0.12312329,  0.26022613, -0.12728322,
#        -0.26218402, -0.05089607,  0.34069896,  0.66453797,  0.3158131 ,
#        -0.30280465, -0.00235894, -0.36971506, -0.28727242,  0.2596369 ,
#         0.22911115,  0.38084638,  0.04658465,  0.19430815, -0.11982727,
#         0.21043025,  0.07248677, -0.5260407 , -0.09633017,  0.28938264,
#         0.0952811 , -0.00512148,  0.2792129 , -0.29928988, -0.088538  ,
#         0.29585886,  0.02992295, -0.24747424,  0.382373  ,  0.2611176 ,
#         0.07357042, -0.4420213 ,  0.18302022, -0.14569338,  0.2085724 ,
#         0.14325866, -0.12686573, -0.03187249,  0.02157154, -0.02989702,
#         0.15716434,  0.36524075,  0.00644294, -0.05562984, -0.2737926 ,
#         0.01491096, -0.50998104, -0.27638283,  0.2676999 , -0.6632062 ,
#         0.31054196,  0.29704332,  0.39025384, -0.01239664,  0.30115393,
#         0.9830213 ,  0.5308705 ,  0.37877938,  0.07688212,  0.35519612,
#        -0.09879415, -0.80299664,  0.2911422 , -0.14649299,  0.42108843,
#        -0.15167132,  0.03755539, -0.06773882, -0.24118474,  0.10316206,
#         0.06192245,  0.157882  , -0.19918592, -0.3295163 ,  0.06120074,
#         0.00255274,  0.45719385,  0.42983243, -0.10501   , -0.18893568,
#        -0.48905066, -0.38970056, -0.80354315, -0.26624534, -0.05874904,
#         0.47505555, -0.46065754, -0.3419014 ,  0.0743309 , -0.00929593,
#         0.18787804, -0.17563558, -0.24616113,  0.06530389, -0.5670311 ,
#         0.6603398 ,  0.08906521,  0.01354342,  0.40171614, -0.37732005,
#        -0.11934616, -0.01070264, -0.12332488, -0.3717427 ,  0.4930208 ,
#         0.29596856, -0.207768  , -0.31914905,  0.13975005,  0.03193976,
#         0.04297966, -0.5930915 , -0.26201797, -0.37621367, -0.17550088],
#       dtype=float32), array([ 0.00363999,  0.20688584,  0.42553374, -0.3782451 ,  0.14067139,
#        -0.0155961 ,  0.32728612,  0.39910465, -0.29284817, -0.20247468,
#         0.24785379,  0.43334278, -0.19200322,  0.00727194, -0.2043552 ,
#         0.12707485,  0.22064835, -0.5086629 ,  0.05326803,  0.72285444,
#         0.03291345,  0.41739327, -0.16640598,  0.65935856, -0.4225446 ,
#        -0.13747641,  0.13032658, -0.13519375,  0.11231019,  0.01448636,
#        -0.7762826 , -0.18237497,  0.05437377,  0.30364418, -0.30850574,
#        -0.03402214,  0.4337953 , -0.24367256, -0.14941478, -0.29861003,
#         0.12389019, -0.14586194, -0.14465639,  0.1554906 ,  0.5068716 ,
#        -0.10563584,  0.2931861 , -0.18463665, -0.09183475, -0.29794034,
#        -0.34547606,  0.14742859, -0.08436394, -0.2668813 ,  0.15840267,
#         0.30427036, -0.01787824, -0.12068334,  0.20130113, -0.22928336,
#         0.5187559 , -0.3107184 , -0.06858863,  0.14853111,  0.37592062,
#        -0.12923974, -0.3897568 , -0.11724519, -0.16023357,  0.12790495,
#         0.38809568,  0.11071843,  0.07645873, -0.12429056,  0.08375208,
#        -0.16935687, -0.49965078, -0.08811466,  0.43963107, -0.15577586,
#         0.45099172, -0.24982558,  0.07866498, -0.02523357, -0.17221844,
#        -0.08762319,  0.10770191,  0.13813736,  0.50020564, -0.04210819,
#         0.11258237, -0.16334353, -0.02989709, -0.23534021, -0.06072669,
#        -0.02126756,  0.8159549 , -0.11071734, -0.2747526 ,  0.10249062,
#        -0.05659104,  0.15373534,  0.02872208, -0.06576481,  0.12316975,
#         0.00168873, -0.35358143,  0.43881065, -0.06293526,  0.05225315,
#         0.32744315,  0.16021016,  0.06221646, -0.1869897 ,  0.15476143,
#         0.5816346 , -0.34076807, -0.03694464,  0.08180269,  0.07223512,
#         0.23025087, -0.15362339, -0.11991403, -0.05658459,  0.32057014,
#        -0.16799483,  0.19173795, -0.5852587 ,  0.5076365 , -0.34654132,
#        -0.03026017, -0.0659816 , -0.21306188,  0.15472554, -0.1518244 ,
#         0.35103872,  0.55555177,  0.3787839 , -0.28686884,  0.45649096,
#         0.7202659 ,  0.34395346,  0.1094957 ,  0.10878501,  0.19926187,
#         0.00398856, -0.30794415,  0.2340227 , -0.3769814 ,  0.14564842,
#        -0.1434314 ,  0.02999014, -0.04849154, -0.25632083,  0.01068555,
#         0.08405856,  0.04781654, -0.0678129 , -0.5061925 ,  0.22482528,
#         0.01662864,  0.11679567,  0.9861132 ,  0.05642969, -0.15901618,
#        -0.369263  , -0.3373817 , -0.5426717 , -0.40285635, -0.242242  ,
#         0.40226516, -0.25237885, -0.17844282, -0.01535919,  0.3684501 ,
#        -0.09173021,  0.19563551, -0.2594733 ,  0.0496824 , -0.03505755,
#         0.5880545 ,  0.05272727, -0.41218305,  0.22202949,  0.03435932,
#        -0.40527272, -0.11269149,  0.0134748 , -0.03398843,  0.25812626,
#         0.47617194,  0.0334588 ,  0.21208677,  0.35886505,  0.00327703,
#         0.03654704, -0.35967702,  0.04605395, -0.2591466 ,  0.03930605],
#       dtype=float32), array([-4.82603945e-02,  6.69806898e-02,  1.32471383e-01, -2.07944632e-01,
#         1.55674174e-01,  1.16017349e-02, -1.42635211e-01,  1.06768221e-01,
#        -3.15071285e-01, -3.82439524e-04,  1.59701556e-01,  9.54999998e-02,
#        -2.37355277e-01,  1.76907897e-01,  6.32866248e-02, -2.02216923e-01,
#         7.19574466e-02, -1.65391579e-01,  8.05765837e-02,  2.54916042e-01,
#        -1.47276163e-01,  4.68792543e-02, -1.64950013e-01, -6.49031624e-02,
#        -2.65199989e-01, -9.20226984e-03, -1.83700576e-01, -2.33130716e-02,
#        -3.15954350e-02, -2.07135171e-01, -1.52576819e-01,  7.07837194e-02,
#        -1.42714456e-01,  1.42278582e-01,  1.78620204e-01, -3.09078628e-03,
#         1.22618340e-01, -1.04556784e-01, -1.68264404e-01, -2.63604909e-01,
#        -2.44776369e-03,  4.43035550e-02,  6.88812733e-02,  4.49885651e-02,
#         5.39594777e-02,  1.32119581e-01, -1.55703813e-01, -2.58696467e-01,
#        -7.03485385e-02,  8.18801001e-02, -1.28841519e-01,  1.92518502e-01,
#        -1.07684068e-01, -8.82383361e-02, -1.67324528e-01,  1.89294070e-02,
#         1.20498836e-01, -4.50075008e-02, -8.63836855e-02, -5.33360243e-02,
#         2.13258460e-01, -1.53654039e-01, -8.92198756e-02,  1.79765537e-01,
#         7.13948086e-02, -7.67998472e-02, -2.15672459e-02, -5.25093451e-03,
#         2.03069225e-01,  8.51546973e-02,  3.70623708e-01, -1.33003101e-01,
#        -9.93034989e-02, -7.24103525e-02,  2.60175858e-03, -1.01825066e-01,
#        -5.67269027e-02,  1.05968164e-02,  4.77448143e-02,  1.33403465e-01,
#         2.53692985e-01,  3.58506888e-02,  1.68802679e-01, -1.65428966e-01,
#        -5.14801443e-02, -1.04436159e-01, -2.29348555e-01, -8.26648250e-02,
#         1.09992020e-01, -1.32299110e-01,  1.70064624e-02, -2.51904398e-01,
#        -3.05828661e-01, -1.90710306e-01, -2.23636422e-02,  7.02587282e-03,
#         1.57930687e-01,  7.13643730e-02, -2.33947784e-02,  2.12641791e-01,
#         9.23261866e-02,  9.04450342e-02, -1.20565884e-01, -1.62445679e-01,
#        -1.25093207e-01,  1.05842382e-01,  2.63567492e-02,  3.88175845e-02,
#        -1.37370735e-01,  8.06311443e-02,  1.51390016e-01, -3.46238911e-02,
#         2.46564429e-02,  2.04474360e-01,  3.78945880e-02, -3.74535173e-02,
#        -6.07415885e-02,  2.04711966e-03, -1.00732997e-01,  1.94692880e-01,
#         1.19967379e-01, -4.14995402e-02, -1.04256503e-01, -1.44222736e-01,
#         6.53415471e-02,  6.61124662e-02,  3.19790691e-02,  6.50977269e-02,
#        -7.37642273e-02, -2.23507565e-02, -6.92337826e-02, -1.55654773e-01,
#         3.74645367e-02,  1.13406643e-01, -3.33745331e-02,  8.77426565e-02,
#         6.99665919e-02,  9.20416489e-02,  7.35564623e-03,  1.42981276e-01,
#         5.98194189e-02,  1.28850088e-01,  6.83581233e-02,  2.43164867e-01,
#        -5.62910475e-02,  8.71916264e-02, -1.26512408e-01,  5.85968271e-02,
#        -5.73157109e-02,  2.29048152e-02, -1.15166880e-01, -7.64952302e-02,
#        -7.95500167e-03, -1.47425860e-01, -9.28587839e-02, -2.19005138e-01,
#         4.57628891e-02, -4.10218090e-02, -1.04054749e-01, -3.95404771e-02,
#        -1.98413953e-02,  2.88871992e-02,  3.94354463e-01, -2.63832998e-03,
#         1.90909833e-01, -1.97878674e-01, -9.91864502e-02,  1.18620589e-01,
#        -3.29961888e-02,  4.26589046e-03,  2.14174196e-01, -1.69481158e-01,
#        -4.14175875e-02,  3.41581628e-02,  1.49258018e-01,  6.66585490e-02,
#         7.32250735e-02,  5.83164133e-02,  6.14147596e-02, -2.19370946e-01,
#         3.94095063e-01, -1.41964378e-02,  2.68819761e-02,  5.38388789e-02,
#        -2.25843750e-02, -2.45397285e-01,  2.06385665e-02, -3.58081385e-02,
#        -2.28330582e-01, -6.05431804e-03,  1.91992775e-01, -2.38819141e-02,
#        -4.31709178e-02,  4.25021984e-02,  3.54026742e-02,  3.72409448e-02,
#        -3.30374002e-01, -8.61288905e-02, -1.99844509e-01, -1.22412451e-01],
#       dtype=float32), array([ 1.59219280e-01,  8.19229484e-02,  2.91897893e-01, -1.76845416e-01,
#         1.49890780e-01, -1.74745306e-01,  8.59781355e-02, -1.65796250e-01,
#        -3.39647651e-01,  6.01705201e-02,  2.14520216e-01,  3.42160285e-01,
#        -6.57406151e-02,  2.04977557e-01,  3.49329319e-04, -2.37710968e-01,
#         4.16027121e-02, -2.53126085e-01,  6.47985488e-02,  6.44820690e-01,
#         3.35494876e-01, -1.11409150e-01, -2.86474470e-02,  1.77412763e-01,
#        -4.19025511e-01, -2.29535580e-01,  1.17604308e-01,  1.37496069e-01,
#         1.29259363e-01, -2.44590282e-01, -2.19952419e-01,  1.63623765e-01,
#        -2.30606481e-01,  1.56111628e-01,  1.44489691e-01,  1.68003380e-01,
#         1.93059713e-01,  1.39133886e-01, -1.53345570e-01, -3.01547617e-01,
#         1.58535719e-01, -8.41549262e-02, -2.07943022e-01,  1.68907881e-01,
#         2.13151574e-01,  2.10139453e-01, -1.49761394e-01, -1.11286059e-01,
#         4.45201434e-02, -3.39127451e-01,  1.09243812e-02,  3.03787559e-01,
#        -1.05101272e-01, -1.61059707e-01, -1.44758850e-01,  2.24878013e-01,
#        -2.24654917e-02, -1.91151962e-01,  1.38249218e-01, -2.22592160e-01,
#         3.03447545e-01, -1.29934981e-01, -1.08553492e-01,  3.48255574e-03,
#         3.84452999e-01,  2.06909538e-03, -3.88608754e-01, -2.10056424e-01,
#         1.23797975e-01, -5.56116737e-02,  3.37279379e-01,  3.16873223e-01,
#        -2.21446771e-02, -2.20423820e-03,  2.22955391e-01, -1.47388309e-01,
#         3.94132175e-02, -2.21030876e-01,  4.29555506e-01, -6.50567338e-02,
#         2.70175695e-01,  1.86507940e-01,  4.28211838e-01,  1.91481616e-02,
#         7.01491237e-02, -1.80496618e-01, -6.49276301e-02,  2.49400318e-01,
#         1.48725018e-01, -1.40479594e-01, -1.36286288e-01, -1.08886778e-01,
#        -4.89761084e-02, -1.75330594e-01, -2.17292048e-02,  1.44607695e-02,
#         4.02668774e-01,  1.76238880e-01, -8.73370096e-03,  1.16311930e-01,
#         1.88794434e-01, -6.05151802e-03, -1.41829252e-01,  1.74699634e-01,
#        -1.62764918e-02, -2.09631532e-01, -1.72451779e-03,  6.79142550e-02,
#        -9.27133262e-02,  6.88161254e-02,  3.34684938e-01, -1.07274890e-01,
#        -1.21833526e-01,  6.51203021e-02,  1.32695317e-01,  1.83046684e-01,
#        -2.65295088e-01,  2.47442707e-01, -4.06284779e-02,  3.42260413e-02,
#         1.64602414e-01,  2.28759330e-02, -3.98502313e-02, -1.86980695e-01,
#         7.82366693e-02,  1.14665762e-01,  2.72587210e-01, -6.48004636e-02,
#         2.22228810e-01, -3.42480093e-01, -2.41966061e-02, -1.10831089e-01,
#         4.97018918e-02, -1.57417312e-01, -2.54077971e-01,  2.87041813e-02,
#         2.96820223e-01,  3.19828153e-01, -1.84964091e-01,  2.51198083e-01,
#         3.18938613e-01,  2.14838997e-01, -3.06180436e-02,  3.53479028e-01,
#         3.53475034e-01, -1.66020077e-02, -6.67621419e-02,  2.46003300e-01,
#        -2.28579655e-01,  4.60619152e-01, -1.01273935e-02, -7.75303319e-02,
#         3.59467417e-02, -1.98158085e-01,  6.88038692e-02, -1.10511340e-01,
#         1.94067881e-01,  3.33375812e-01, -2.15065498e-02,  9.83791798e-02,
#         7.48329759e-02, -2.74698675e-01,  2.30237216e-01, -2.78869390e-01,
#        -2.88444996e-01, -2.62033969e-01, -8.18905458e-02, -2.25096583e-01,
#        -2.10871249e-01, -2.54164308e-01,  1.99203715e-01, -3.13015610e-01,
#        -4.26197089e-02,  3.11506003e-01,  4.59415644e-01, -6.00654818e-02,
#        -2.81342007e-02, -2.07101822e-01,  3.63646328e-01, -2.27588162e-01,
#         3.30085337e-01, -1.18135952e-03,  8.69547129e-02,  1.80039543e-03,
#        -1.79516211e-01, -6.99087754e-02, -1.89377308e-01, -5.29873557e-02,
#        -3.57219130e-01,  2.44028755e-02,  3.46796900e-01, -1.91832736e-01,
#         6.55826600e-03,  3.27302739e-02,  1.44370347e-01, -1.74957141e-02,
#        -3.13237369e-01, -2.16763228e-01, -1.44332364e-01,  2.68351962e-03],
#       dtype=float32), array([-0.04218627,  0.09071103,  0.1379083 , -0.20756903,  0.18134227,
#         0.01050401, -0.14727658,  0.12453078, -0.31343985,  0.00773436,
#         0.1508559 ,  0.0840322 , -0.23675495,  0.16311274,  0.08709539,
#        -0.20599893,  0.04304952, -0.17325082,  0.04813354,  0.2601162 ,
#        -0.13868669,  0.0217    , -0.15073568, -0.08036311, -0.2643565 ,
#        -0.00677775, -0.17065665, -0.01784982, -0.03724829, -0.18042807,
#        -0.14575367,  0.0829709 , -0.12569979,  0.1432419 ,  0.19850148,
#         0.00218271,  0.13640282, -0.09646396, -0.17301303, -0.2683967 ,
#         0.00072048,  0.01947357,  0.05305345,  0.05108947,  0.06017409,
#         0.13650024, -0.15754354, -0.26533252, -0.06631962,  0.09466562,
#        -0.14423333,  0.19805728, -0.09863995, -0.07474117, -0.1566649 ,
#         0.03994073,  0.12558235, -0.06540169, -0.06481995, -0.03578443,
#         0.22801484, -0.15984209, -0.10916284,  0.159973  ,  0.0635431 ,
#        -0.08838747, -0.02674526, -0.00596344,  0.19795784,  0.10965724,
#         0.3917442 , -0.13513952, -0.11334329, -0.04811238, -0.00952825,
#        -0.12080655, -0.05352633,  0.00997647,  0.04791394,  0.1305609 ,
#         0.23419939,  0.05725399,  0.16297993, -0.17538661, -0.08066983,
#        -0.10958272, -0.24446853, -0.07606643,  0.11317553, -0.13306488,
#         0.01566839, -0.2240992 , -0.30155283, -0.18722636, -0.03047329,
#         0.01548543,  0.16487412,  0.07556809, -0.0238415 ,  0.23721236,
#         0.08381151,  0.08381829, -0.1332646 , -0.18697423, -0.11030696,
#         0.10491962,  0.01459967,  0.02845079, -0.13851735,  0.06771234,
#         0.17988096, -0.03119212,  0.02427768,  0.22561441,  0.04982755,
#        -0.06475803, -0.04997727, -0.02318603, -0.11521108,  0.17692249,
#         0.11055822, -0.0414978 , -0.08642811, -0.13437103,  0.04509594,
#         0.05094282,  0.0354297 ,  0.04543851, -0.07685469, -0.00460722,
#        -0.0668142 , -0.16475205,  0.0380001 ,  0.12100855, -0.03329641,
#         0.09535513,  0.0699754 ,  0.08401027,  0.02901091,  0.1420026 ,
#         0.05117481,  0.10984314,  0.05755613,  0.24847381, -0.07202933,
#         0.07771178, -0.12765588,  0.06969389, -0.03626722,  0.01840511,
#        -0.09521399, -0.07336368, -0.02950164, -0.14799201, -0.09846205,
#        -0.23726048,  0.06098497, -0.06530432, -0.07876956, -0.04840664,
#        -0.02501742,  0.05992718,  0.41217846,  0.00500619,  0.19832021,
#        -0.1905759 , -0.12547871,  0.11854792, -0.03212625,  0.02504453,
#         0.1955062 , -0.17093726, -0.03632822,  0.06152175,  0.1344405 ,
#         0.07585406,  0.0590526 ,  0.05148198,  0.05973966, -0.21461393,
#         0.39557862, -0.02136351,  0.07602475,  0.02686146, -0.02048407,
#        -0.24384595,  0.03001309, -0.03625827, -0.2143494 , -0.00962973,
#         0.16500567, -0.02289886, -0.05494933,  0.06117946,  0.02697849,
#         0.03049902, -0.3207332 , -0.08802047, -0.17456181, -0.11391524],
#       dtype=float32)]
# np.shape(v2s)
# (5, 200)
# vsim
# [0.9999999  0.62694025 0.5738347  0.633248   0.57345486]
# np.shape(vsim)
# (5,)

# %%
import numpy as np
cmtId2Vec ={}
for doc_id in range(len(doc2VecTrain)):
    inferred_vector = model.infer_vector(doc2VecTrain[doc_id].words)
    if  not np.isnan(inferred_vector).any() and not np.isinf(inferred_vector).any(): 
        cmtId = doc2VecTrain[doc_id].tags
        cmtId2Vec[cmtId[0]] = inferred_vector

# %%
print (len(cmtId2Vec))
# Out:
# 202778

# %%
#emojis = re.compile(u'([\u2600-\u27BF])|([\uD83C][\uDF00-\uDFFF])|([\uD83D][\uDC00-\uDE4F])|([\uD83D][\uDE80-\uDEFF])',flags=re.UNICODE)
#emojis

# %%
def write_each_char(string,out):
    for i in range(len(string)):
        try:
            out.write(string[i])
        except TypeError:
            pass
        except UnicodeEncodeError as err:
            print ("write failed for char: "+string[i] + str(err))

# %%
def printRandClosest(data, model, trainingSet, closestNcommentsFile, topn, n):
    import string
    translator = str.maketrans('', '', string.punctuation)
    
    import re
    try:
        # UCS-4
        emojis = re.compile(u'([\U00002600-\U000027BF])|([\U0001f300-\U0001f64F])|([\U0001f680-\U0001f6FF])', flags=re.UNICODE)
    except re.error:
        # UCS-2
        emojis = re.compile(u'([\u2600-\u27BF])|([\uD83C][\uDF00-\uDFFF])|([\uD83D][\uDC00-\uDE4F])|([\uD83D][\uDE80-\uDEFF])',flags=re.UNICODE)
        
    non_blank_whitespace = re.compile("[\t\n\r\f\v]")
    
    for i in range (n):
        randindex = random.randint(0,len (trainingSet))
        #print(randindex)
        #print("CMTid:" + str(doc2VecTrain[randindex][1][0]))
        #print (doc2VecTrain[randindex][0])
        try:
            words = trainingSet[randindex][0]
            tags = trainingSet[randindex][1]
            #for words, tags in trainingSet:
            cmtID = tags[0]
            comment = ' '.join(filter(None, words))
            closestNcommentsFile.write(comment + ",")
            themeVector = model.infer_vector(words)
            #print(themeVector)
            mostSim =  model.docvecs.most_similar([themeVector], topn=topn)
            count = 0
            for id,dist in mostSim[:topn]:
                closestNcommentsFile.write(str(dist) + ':')
                comment = data.loc[id]['text']

                try: 
                    if len(comment) > 0:
                        comment = str(comment)
                        comment = emojis.sub(" emoji ", comment)
                        comment = non_blank_whitespace.sub(" ", comment)
                        comment = comment.lower().translate(translator)

                        if count < topn-1:
                            #closestNcommentsFile.write(comment +",")
                            strng = comment+','
                            write_each_char(strng,closestNcommentsFile)
                        else:
                            #closestNcommentsFile.write(comment +"\n")
                            strng = comment+'\n'
                            write_each_char(strng,closestNcommentsFile)
                        count += 1
                except TypeError:
                    pass
                except UnicodeEncodeError as err:
                    print ("printing failed for : "+comment + str(err))
        except:
            print(randindex)

# %%
from pathlib import Path

def testNumIters(data, model, size, doc2VecTrain, baseIters, epochs,root, n=1000,topn = 10 ):
    for i in range (baseIters,epochs*baseIters,baseIters):   
        # %time model.train(doc2VecTrain, total_examples=model.corpus_count, epochs = model.iter)
        fileName  = root + ".size" + str(size)+ ".iter" + str(i) + ".csv"
        closestNcommentsFile = open (fileName,"w")
        printRandClosest(data, model, doc2VecTrain, closestNcommentsFile, topn, n)
        closestNcommentsFile.close()
    
    
def testVectorSizeAndIters (data, doc2VecTrain, root, min_count = 10, baseIters= 100, epochs = 10):
    sizes = [25,50,100,150,200, 250,300]
    for size in sizes:
        model = gensim.models.doc2vec.Doc2Vec(size=size, min_count=min_count, iter=baseIters, dm=0)
        try:
            model.build_vocab(doc2VecTrain)
        except:
            print( "model.build_vocab(doc2VecTrain) failed ")
        testNumIters(data, model, size, doc2VecTrain,baseIters, epochs, root)
        
randClosest = output_root + "_rand_closest"
#testVectorSizeAndIters(raw_data, doc2VecTrain, randClosest)

# %%
def printClosest(model, trainingSet, closestNcommentsFile, topn):
    import string
    translator = str.maketrans('', '', string.punctuation)
    for words, tags in trainingSet:
        cmtID = tags[0]
        comment = ' '.join(filter(None, words))
        closestNcommentsFile.write(comment + ",")
        themeVector = model.infer_vector(words)
        mostSim =  model.docvecs.most_similar([themeVector], topn=topn)
        count = 0
        for id,dist in mostSim[:topn]:
            count += 1
            closestNcommentsFile.write(str(dist) + ':')
            comment = data.loc[data['CmtID'] == id]['Comment']
            if len(comment) > 0:
                comment = str(comment.item())
                comment = comment.lower().translate(translator)
                if count < topn:
                    closestNcommentsFile.write(comment +",")
                else:
                    closestNcommentsFile.write(comment +"\n")

# %%
from pathlib import Path
closestComments = output_root + "_closest_comments.csv"

my_file = Path(closestComments)
if not my_file.exists():
    topn = 10
    n=1000
    closestNcommentsFile = open (closestComments,"w")
    #printClosest(model, doc2VecTrain, closestNcommentsFile, topn) 
    # %time printRandClosest(raw_data, model, doc2VecTrain, closestNcommentsFile, topn, n)
    closestNcommentsFile.close()

# %%
def createClusterAlgorithms( raw_data, cmtVectors):
    from collections import Counter
    import numpy as np
    import nltk
    import sklearn
    import datetime

    from sklearn.cluster import DBSCAN
    from sklearn.cluster import MiniBatchKMeans
    from sklearn import metrics
    from sklearn.datasets.samples_generator import make_blobs
    from sklearn.preprocessing import StandardScaler 
    from sklearn.cluster import Birch
    from sklearn import mixture
    from nltk.cluster.kmeans import KMeansClusterer
    from nltk.cluster.gaac import GAAClusterer
    from sklearn import cluster, datasets, mixture
    from sklearn.neighbors import kneighbors_graph

    X = StandardScaler().fit_transform(cmtVectors)


    params = {'quantile': .3,
            'eps': .3,
            'damping': .9,
            'preference': -200,
            'n_neighbors': 10,
            'n_clusters': 20}





    # ============
    # Create cluster objects
    # ============
    import time
    import metrics
    
    secs = time.clock()
     # connectivity matrix for structured Ward
    connectivity = kneighbors_graph(
        X, n_neighbors=params['n_neighbors'], include_self=False)
    # make connectivity symmetric
    connectivity = 0.5 * (connectivity + connectivity.T)
    secs = time.clock() -secs
    print ("Time connectivity" + str(secs) )

    secs = time.clock()
    dbscan = cluster.DBSCAN(eps=params['eps']).fit(X)
    clusterAlgLabelAssignmentsSD= dbscan.labels_.astype(np.int)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Dbscan" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSD, metric = 'cosine')
    print ("Silhouette Dbscan" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSD)  
    print ("Calinski Harabaz Dbscan" + str(calinski_harabaz))
    
    secs = time.clock()
    affinity_propagation = cluster.AffinityPropagation(damping=params['damping'], preference=params['preference']).fit(X)
    clusterAlgLabelAssignmentsSAP= affinity_propagation.predict(X)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Affinity Propagation" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSAP, metric = 'cosine')
    print ("Silhouette Affinity Propagation" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSAP)  
    print ("Calinski Harabaz Affinity Propagation" + str(calinski_harabaz))
    

    secs = time.clock()
    average_linkage = sklearn.cluster.AgglomerativeClustering(linkage="average", 
        affinity="cosine",n_clusters=params['n_clusters'], connectivity=connectivity).fit(X)
    clusterAlgLabelAssignmentsSAG= average_linkage.labels_.astype(np.int)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Agglomerative" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSAP, metric = 'cosine')
    print ("Silhouette Agglomerative" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSAP)  
    print ("Calinski Harabaz Agglomerative" + str(calinski_harabaz))
    
    

    secs = time.clock()
    birch = sklearn.cluster.Birch(n_clusters=params['n_clusters']).fit(X)
    clusterAlgLabelAssignmentsSB= birch.predict(X)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Birch" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSB, metric = 'cosine')
    print ("Silhouette Birch" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSB)  
    print ("Calinski Harabaz Birch" + str(calinski_harabaz))
    
    

    secs = time.clock()
    clusterAlgSGN = mixture.GaussianMixture(n_components=params['n_clusters'], covariance_type='full').fit(X)
    clusterAlgLabelAssignmentsSGN= clusterAlgSGN.predict(X)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Gaussian Mixture Normalized" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSGN, metric = 'cosine')
    print ("Silhouette Gaussian Mixture Normalized" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSGN)  
    print ("Calinski Harabaz Gaussian Mixture Normalized" + str(calinski_harabaz))
    
    

    secs = time.clock()
    clusterAlgSG = mixture.GaussianMixture(n_components=params['n_clusters'], covariance_type='full').fit(cmtVectors)
    clusterAlgLabelAssignmentsSG= clusterAlgSG.predict(cmtVectors)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Gaussian Mixture" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSG, metric = 'cosine')
    print ("Silhouette Gaussian Mixture" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSG)  
    print ("Calinski Harabaz Gaussian Mixture" + str(calinski_harabaz))
    
    

    secs = time.clock()
    clusterAlgSKN = MiniBatchKMeans(n_clusters=params['n_clusters']).fit(X)
    clusterAlgLabelAssignmentsSKN= clusterAlgSKN.predict(X)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Mini Batch Kmeans Normalized" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSKN, metric = 'cosine')
    print ("Silhouette Mini Batch Kmeans Normalized" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSKN)  
    print ("Calinski Harabaz Mini Batch Kmeans Normalized" + str(calinski_harabaz))
    
    

    secs = time.clock()
    clusterAlgSK = MiniBatchKMeans(n_clusters=params['n_clusters']).fit(cmtVectors)
    clusterAlgLabelAssignmentsSK= clusterAlgSK.predict(cmtVectors)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Mini Batch Kmeans" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSK, metric = 'cosine')
    print ("Silhouette Mini Batch Kmeans" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSK)  
    print ("Calinski Harabaz Mini Batch Kmeans" + str(calinski_harabaz))
    
    
    
    secs = time.clock() 
     # estimate bandwidth for mean shift
    bandwidth = sklearn.cluster.estimate_bandwidth(X, quantile=params['quantile'])
    secs = time.clock() -secs
    print ("Time Mean Shift bandwidth" + str(secs) )
 
    secs = time.clock()   
   
    ms = cluster.MeanShift(bandwidth=bandwidth, bin_seeding=True).fit(X)
    clusterAlgLabelAssignmentsSM= ms.predict(X)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Mean Shift" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSM, metric = 'cosine')
    print ("Silhouette Mean Shift" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSM)  
    print ("Calinski Harabaz Mean Shift" + str(calinski_harabaz))

    
    secs = time.clock()
    ward = sklearn.cluster.AgglomerativeClustering(n_clusters=params['n_clusters'], linkage='ward',connectivity=connectivity).fit(X)
    clusterAlgLabelAssignmentsSW= ward.labels_.astype(np.int)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Agglomerative Ward" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSW, metric = 'cosine')
    print ("Silhouette Agglomerative Ward" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSW)  
    print ("Calinski Harabaz Agglomerative Ward" + str(calinski_harabaz))
  
    
    
    
    
    secs = time.clock()
    spectral = sklearn.cluster.SpectralClustering(
        n_clusters=params['n_clusters'], eigen_solver='arpack',
        affinity="cosine")
    try:
        clusterAlgLabelAssignmentsSS= None
        spectral = spectral.fit(X)
    except ValueError as e:
        print("error: "+ str(e))
        print(X)
    else:
        clusterAlgLabelAssignmentsSS= spectral.labels_.astype(np.int)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time Spectral" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsSS, metric = 'cosine')
    print ("Silhouette Spectral" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsSS)  
    print ("Calinski Harabaz Spectral" + str(calinski_harabaz))
    

    secs = time.clock()
    clusterAlgNK = KMeansClusterer(params['n_clusters'], distance=nltk.cluster.util.cosine_distance, repeats=25, avoid_empty_clusters=True)
    clusterAlgLabelAssignmentsNK = clusterAlgNK.cluster(cmtVectors, assign_clusters=True)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time NLTK Kmeans" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsNK, metric = 'cosine')
    print ("Silhouette NLTK Kmeans" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsNK)  
    print ("Calinski Harabaz NLTK Kmeans" + str(calinski_harabaz))

    secs = time.clock()
    clusterAlgNG = GAAClusterer(num_clusters=params['n_clusters'], normalise=True, svd_dimensions=None)
    clusterAlgLabelAssignmentsNG = clusterAlgNG.cluster(cmtVectors, assign_clusters=True)
    print(datetime.datetime.utcnow())
    secs = time.clock() -secs
    print ("Time NLTK GAA" + str(secs) )
    silhouette = metrics.silhouette_score(X, clusterAlgLabelAssignmentsNG, metric = 'cosine')
    print ("Silhouette NLTK GAA" + str(silhouette))
    calinski_harabaz = metrics.calinski_harabaz_score(X, clusterAlgLabelAssignmentsNG)  
    print ("Calinski Harabaz NLTK GAA" + str(calinski_harabaz))
  
    algorithms = { 'SM': clusterAlgLabelAssignmentsSM, 
              'SW':clusterAlgLabelAssignmentsSW, 
              'SS':clusterAlgLabelAssignmentsSS, 
              'SD':clusterAlgLabelAssignmentsSD, 
              'SAG':clusterAlgLabelAssignmentsSAG, 
              'SAP':clusterAlgLabelAssignmentsSAP, 
              'SB':clusterAlgLabelAssignmentsSB, 
              'SG': clusterAlgLabelAssignmentsSG, 
              'SGN':clusterAlgLabelAssignmentsSGN, 
              'SK':clusterAlgLabelAssignmentsSK, 
              'SKN':clusterAlgLabelAssignmentsSKN, 
              'NK':clusterAlgLabelAssignmentsNK, 
              'NG':clusterAlgLabelAssignmentsNG
             }
    return (algorithms)

# %%
import pickle
from pathlib import Path

#limit the number to cluster because the order of alg is n^2 or more
n = 20000
m = min (len(raw_data),n)

print(m)

randIndicies = [random.randint(0,len (raw_data)) for i in range(m)]

#cmtIds = [raw_data.loc[i,'SingularityNetID'] for i in range(len(raw_data)) ]
cmtIds = [raw_data.loc[i,'SingularityNetID'] for i in randIndicies ]
cmtVectors = [np.array(cmtId2Vec[cmtId]) for cmtId in cmtIds if cmtId in cmtId2Vec]


algorithms_pickle = output_root + "_algorithms.p"
my_file = Path(algorithms_pickle)
if my_file.exists():
    # %time algorithms = pickle.load ( open (algorithms_pickle, "rb"))
else:
    # %time algorithms = createClusterAlgorithms(raw_data, cmtVectors)
    pickle.dump (algorithms, open (algorithms_pickle, "wb"))
# Out:
# 20000
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 24 ms

# %%
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity

  
allvectors = {}

for name, clusterLabels in algorithms.items(): 
    centroidName = 'Centroid'+name
    clusterName = 'Cluster'+name
    raw_data[clusterName]= -1
    raw_data[centroidName]= -1
    if clusterLabels is not None:  #and len(set(clusterLabels)) < max_clusters 

        counter = Counter()
        vectors = {}
        for i in range(len(clusterLabels)):
            cluster = clusterLabels[i]
            counter[cluster]+= 1
            raw_data.loc[raw_data["SingularityNetID"]==cmtIds[i], clusterName] = cluster
            if cluster not in vectors:
                vectors[cluster] = []
            vectors[cluster].append(cmtVectors[i])
        allvectors[name] = vectors
        
allCentroids = {} 
for name, vectors in allvectors.items(): 
    thisAlgCentroids = {}
    allCentroids[name] = thisAlgCentroids
    for cluster,clustervecs in vectors.items():
        
        clusterName = 'Cluster'+name
        clusterString = str(cluster)
        numMembers = len(clustervecs)
        centroid = np.mean (clustervecs, axis = 0) if numMembers >1 else clustervecs[0]
        #print ('centroid')
        #print (centroid)
        if centroid.size:
            thisAlgCentroids[cluster] = centroid
            
cluster2cmtId = {}
for name, clusterLabels in algorithms.items(): 
    if clusterLabels is not None:
        for cmtId,cluster in zip(cmtIds,clusterLabels):
            if cmtId > -1: 
                #make a list name->cluster->cmtIds in cluster
                if name not in cluster2cmtId:
                    cluster2cmtId[name] = {}
                if cluster not in cluster2cmtId[name]:
                    cluster2cmtId[name][cluster] = []
                cluster2cmtId[name][cluster].append(cmtId)
#print ('cluster2cmtId')
#print (cluster2cmtId)

cluster2similarities = {}                
for name, clusterDict in cluster2cmtId.items(): 
    for cluster, cmtList in clusterDict.items():
        #print('name')
        #print(name)
        #print('cluster')
        #print(cluster)
        #print ('cmtList')
        #print (cmtList)
        vecs = [model.docvecs[cmtId] for cmtId in cmtList]
        #print ('np.shape(vecs)')
        #print (np.shape(vecs))
        centroidName = 'Centroid'+name
        centroid = allCentroids[name][cluster]
        #print ('np.shape(centroid)')
        #print (np.shape(centroid))
        #make a list name->cluster->similarities in cluster
        if name not in cluster2similarities:
            cluster2similarities[name] = {}
        #print('centroid')
        #print(centroid)
        #print('vecs')
        #print(vecs)
        cluster2similarities[name][cluster] = model.wv.cosine_similarities(centroid,vecs)
        #print ('np.shape(cluster2similarities[name][cluster])')
        #print (np.shape(cluster2similarities[name][cluster]))
#print ('cluster2similarities')
#print (cluster2similarities)

for name, clusterDict in cluster2similarities.items(): 
    print("\n\nAlgorithm " + name)
    for cluster, simvecArray in clusterDict.items():
        #print ('np.shape(simvecArray)')
        #print (np.shape(simvecArray))
        #print ('np.shape(cluster2cmtId[name][cluster])')
        #print (np.shape(cluster2cmtId[name][cluster]))
        simTuples = list(zip(cluster2cmtId[name][cluster],simvecArray))
        simTuples.sort(reverse=True, key=lambda tup: tup[1])
        size = len(simTuples)
        top5 = simTuples[:5] 
        index = 0
        print ('\ncluster '+ str(cluster) + ' has '+ str(size)+ ' docs like:\n' )
        for cmtId,similarity in top5:
            comment = raw_data.loc[cmtId,['text']]
            index += 1
            print(str(index)+". similarity: " + str(similarity))
            print(comment)                       
             
        for cmtId,similarity in simTuples:                 
            centroidName = 'Centroid'+name
            #print ('cmtId')
            #print (cmtId)
            #print ('centroidName')
            #print (centroidName)
            #print ('similarity')
            #print (similarity)
            raw_data.loc[raw_data["SingularityNetID"]==cmtId, centroidName] = similarity
          
raw_data.to_csv(raw_data_path_clustered)
# Out:
# Algorithm SM
#
# cluster 0 has 19839 docs like:
#
# 1. similarity: 0.8008956
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 2. similarity: 0.8008956
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 3. similarity: 0.7976871
# text    To me, you are perfect!
# Name: 155521, dtype: object
# 4. similarity: 0.79274845
# text    https://t.co/ITMZj5yGZj it must hurt!
# Name: 143949, dtype: object
# 5. similarity: 0.791909
# text    @ne14phish Nice one!
# Name: 88103, dtype: object
#
#
# Algorithm SW
#
# cluster 1 has 329 docs like:
#
# 1. similarity: 0.7508233
# text    #imvotingbecause I'm over corruption
# Name: 49915, dtype: object
# 2. similarity: 0.72016823
# text    Great! I liked it! http://t.co/pZxpxusKfA
# Name: 59404, dtype: object
# 3. similarity: 0.71610045
# text    RT @deray: what? https://t.co/btzrkGfxSX
# Name: 171837, dtype: object
# 4. similarity: 0.70064354
# text    RT @bon98021883: "Jeff Sessions" https://t.co/z7OpiBgfB1
# Name: 180889, dtype: object
# 5. similarity: 0.6986265
# text    It's a warning\r\nDon't be a fool https://t.co/Y9Xrd6yTTG
# Name: 12063, dtype: object
#
# cluster 5 has 2238 docs like:
#
# 1. similarity: 0.7819177
# text    lol it is very funny https://t.co/5G3vJv8Uft
# Name: 7519, dtype: object
# 2. similarity: 0.78028566
# text    Buy
# Name: 24313, dtype: object
# 3. similarity: 0.7723429
# text    #Economy http://t.co/akSN1ut1o4
# Name: 132374, dtype: object
# 4. similarity: 0.77037984
# text    #AndThenIShouldHaveSaid BET!
# Name: 146979, dtype: object
# 5. similarity: 0.7674643
# text    #ICelebrateTrumpWith being OKAY https://t.co/iRqiXV3HtC
# Name: 154704, dtype: object
#
# cluster 19 has 2546 docs like:
#
# 1. similarity: 0.79960597
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 2. similarity: 0.79189074
# text    #InformTheElectors\r\nof what? the results? https://t.co/A6bHHW8WJs
# Name: 165829, dtype: object
# 3. similarity: 0.78239256
# text    #makemusicreligious Crucify were a boy
# Name: 65175, dtype: object
# 4. similarity: 0.78071576
# text    I'll be fighting for you.
# Name: 194206, dtype: object
# 5. similarity: 0.7767777
# text    Come break me down
# Name: 62208, dtype: object
#
# cluster 14 has 2149 docs like:
#
# 1. similarity: 0.78810245
# text    @ChesterCityNews she is strong!
# Name: 46052, dtype: object
# 2. similarity: 0.7879538
# text    @POTUS_Tweets Sure
# Name: 89548, dtype: object
# 3. similarity: 0.78703195
# text    We wont forget âð¿âð¿ #HappyBirthdayMalcolmX https://t.co/iYFUo0JneQ
# Name: 76718, dtype: object
# 4. similarity: 0.7851583
# text    The Full Housemartins  #AddABandToATVShow
# Name: 37203, dtype: object
# 5. similarity: 0.7841793
# text    15 minutes!
# Name: 185989, dtype: object
#
# cluster 2 has 2298 docs like:
#
# 1. similarity: 0.78386486
# text    am I wrong?? lol https://t.co/ooHBOoppJW
# Name: 56985, dtype: object
# 2. similarity: 0.7832123
# text    that`s what for they like us((  https://t.co/6LbByeQjBf
# Name: 163575, dtype: object
# 3. similarity: 0.7786997
# text    Happy #InternationalWomensDay https://t.co/WPP7b07BfJ
# Name: 123364, dtype: object
# 4. similarity: 0.77274066
# text    @ForkTongueRoad awesome!
# Name: 18781, dtype: object
# 5. similarity: 0.7693975
# text    @steezynun LMAOO I feel you
# Name: 180235, dtype: object
#
# cluster 3 has 2053 docs like:
#
# 1. similarity: 0.7861762
# text    #ReasonsIAintInARelationship I have no idea.... https://t.co/9MI00wFmCN
# Name: 183143, dtype: object
# 2. similarity: 0.78415424
# text    They are awesome! http://t.co/kUcRfps534
# Name: 146795, dtype: object
# 3. similarity: 0.7779838
# text    #OnMyBirthdayCake literally https://t.co/4vG1k4an5W
# Name: 60915, dtype: object
# 4. similarity: 0.77423567
# text    Happy #InternationalWomensDay https://t.co/yHxfK3yVI3
# Name: 21647, dtype: object
# 5. similarity: 0.7682082
# text    I #MustBeBanned
# Name: 93950, dtype: object
#
# cluster 0 has 451 docs like:
#
# 1. similarity: 0.78068376
# text    #ThingsPeopleOnTwitterLike stuff....
# Name: 105987, dtype: object
# 2. similarity: 0.7677926
# text    We all matter #PoliceColor
# Name: 40986, dtype: object
# 3. similarity: 0.75082594
# text    #IslamKills https://t.co/b0BnDBN7kn
# Name: 40003, dtype: object
# 4. similarity: 0.7495617
# text    #IHatePokemonGoBecause they keep patching my hax.
# Name: 68301, dtype: object
# 5. similarity: 0.7382898
# text    #WeirdDaysToRelive MONDAY
# Name: 123387, dtype: object
#
# cluster 7 has 556 docs like:
#
# 1. similarity: 0.78554523
# text    https://t.co/ITMZj5yGZj it must hurt!
# Name: 143949, dtype: object
# 2. similarity: 0.7781858
# text    guys! Guys?? https://t.co/gZUtFmu1RI
# Name: 85628, dtype: object
# 3. similarity: 0.77278006
# text    Those lads are heroes! #DDayInMyHeart
# Name: 34958, dtype: object
# 4. similarity: 0.7678651
# text    #ReasonsToGetDivorced no brain
# Name: 61846, dtype: object
# 5. similarity: 0.7672081
# text    I love it! https://t.co/2aHveE1f7l
# Name: 73204, dtype: object
#
# cluster 10 has 1680 docs like:
#
# 1. similarity: 0.77963835
# text    Ovi #seriously https://t.co/cq9goQVXak
# Name: 202766, dtype: object
# 2. similarity: 0.7781638
# text    Oh boy. #TimeTravelerProblems
# Name: 163902, dtype: object
# 3. similarity: 0.7750846
# text    the chance to be the 2017 Wickerman"
# Name: 182670, dtype: object
# 4. similarity: 0.77381414
# text    https://t.co/x4v6kyURnl beautiful!
# Name: 157519, dtype: object
# 5. similarity: 0.7728705
# text    I feel the same! http://t.co/hVDQeAtfb6
# Name: 161016, dtype: object
#
# cluster 4 has 388 docs like:
#
# 1. similarity: 0.7736504
# text    change who you are!
# Name: 78339, dtype: object
# 2. similarity: 0.742038
# text    "#WhatIWantForChristmasIn4Words
# Name: 154082, dtype: object
# 3. similarity: 0.7264716
# text    RT @JustDesmund: It does!!! Lmao https://t.co/7RIO0uP1aH
# Name: 46647, dtype: object
# 4. similarity: 0.7247365
# text    RT @the1975: // N O R T H A M E R I C A 2 0 1 7 - T I C K E T S O N S A L E N O W // L O V E https://t.co/SuBdXeAx8v https://t.co/xGrokKRo4o
# Name: 158365, dtype: object
# 5. similarity: 0.6853027
# text    https://t.co/axfDGGoIKn favorite part of anaconda
# Name: 13026, dtype: object
#
# cluster 9 has 326 docs like:
#
# 1. similarity: 0.78146493
# text    To me, you are perfect!
# Name: 155521, dtype: object
# 2. similarity: 0.7626113
# text    @Jenn_Abrams Ha ha!
# Name: 117512, dtype: object
# 3. similarity: 0.7562252
# text    #SometimesTwitterMakesMe momentarily interesting o.0
# Name: 172602, dtype: object
# 4. similarity: 0.73811126
# text    Who knows, who knows.. https://t.co/J2AruOej5u
# Name: 72827, dtype: object
# 5. similarity: 0.6864926
# text    RT @OfficialSPGB: @realDonaldTrump @RudyGiuliani https://t.co/JBCH4WLzlJ
# Name: 17677, dtype: object
#
# cluster 12 has 1067 docs like:
#
# 1. similarity: 0.7934232
# text    @ne14phish Nice one!
# Name: 88103, dtype: object
# 2. similarity: 0.78983575
# text    Yes! https://t.co/QMfAV24pbC
# Name: 153428, dtype: object
# 3. similarity: 0.7693607
# text    sometimes https://t.co/xVZtBdzfO3
# Name: 177187, dtype: object
# 4. similarity: 0.7641306
# text    #AddCartoonsToHistory @midnight"
# Name: 5947, dtype: object
# 5. similarity: 0.7576685
# text    You had me at Hellboy.    #OneWordOffMovieQuotes  @midnight
# Name: 2641, dtype: object
#
# cluster 18 has 763 docs like:
#
# 1. similarity: 0.772074
# text    #IGetDepressedWhen he's away from me.
# Name: 134688, dtype: object
# 2. similarity: 0.7700815
# text    #GiftIdeasForPoliticians truth serum
# Name: 135239, dtype: object
# 3. similarity: 0.75744295
# text    I AM WATCHING YOU!
# Name: 186801, dtype: object
# 4. similarity: 0.75549954
# text    The Doctor Who #AddABandToATVShow
# Name: 78504, dtype: object
# 5. similarity: 0.7475898
# text    I came in like a Canniballlllllll #SongsHannibalWouldSing https://t.co/vWs7ceAc84
# Name: 66192, dtype: object
#
# cluster 13 has 803 docs like:
#
# 1. similarity: 0.80385625
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 2. similarity: 0.76458853
# text    #My4WordNewYearsResolution Not jinxing my resolution(s).
# Name: 21181, dtype: object
# 3. similarity: 0.7494866
# text    @amandadsmith1 Sorry
# Name: 25639, dtype: object
# 4. similarity: 0.7454016
# text    Danger! Danger! http://t.co/54W2HojoTw
# Name: 49530, dtype: object
# 5. similarity: 0.7354819
# text    #WhatIWantForChristmasIn4Words"
# Name: 11498, dtype: object
#
# cluster 17 has 309 docs like:
#
# 1. similarity: 0.76001865
# text    #unlikelythingsheardatWalMart I'm with her! #hillaryclinton
# Name: 173976, dtype: object
# 2. similarity: 0.7562548
# text    Happy #InternationalWomensDay https://t.co/HvxEHNKClb
# Name: 193071, dtype: object
# 3. similarity: 0.7066583
# text    RT @CarolynsGeekOut: #NoConfederate ready for it. https://t.co/Nw37yYYaMA
# Name: 37255, dtype: object
# 4. similarity: 0.70347923
# text    RT @tinkerbell35721: #YouCanTellImHipCos he's my dad https://t.co/2wJSGEyMmm
# Name: 92915, dtype: object
# 5. similarity: 0.6979786
# text    RT @RealAlexJones: https://t.co/bNTTgFkuz4
# Name: 55519, dtype: object
#
# cluster 8 has 714 docs like:
#
# 1. similarity: 0.7798522
# text    He deserved it https://t.co/Ou3ArTHqJ8
# Name: 177015, dtype: object
# 2. similarity: 0.75838274
# text    Bonjour Twitter ! #monpremierTweet
# Name: 81175, dtype: object
# 3. similarity: 0.74978626
# text    #ThingsThatComeFromFlorida refugees https://t.co/IAXaECEmz2
# Name: 90080, dtype: object
# 4. similarity: 0.74369663
# text    RT @_bajan_: Exactly ! https://t.co/o4eAvHCJeG
# Name: 47926, dtype: object
# 5. similarity: 0.7408888
# text    #Millennials https://t.co/Y8zSirs2co
# Name: 147719, dtype: object
#
# cluster 11 has 290 docs like:
#
# 1. similarity: 0.77101445
# text    @Jenn_Abrams ðð
# Name: 122822, dtype: object
# 2. similarity: 0.76379335
# text    #MakeTVShowsAustralian Boomerang? M'Lord?
# Name: 125358, dtype: object
# 3. similarity: 0.7432774
# text    https://t.co/kpwgaUrE04 yeah, man)))
# Name: 66668, dtype: object
# 4. similarity: 0.736845
# text    @AlanaMorgan24 How cute
# Name: 154029, dtype: object
# 5. similarity: 0.7163787
# text    RT @TalibKweli: I am. And? https://t.co/2S05GnsLLM
# Name: 152498, dtype: object
#
# cluster 15 has 211 docs like:
#
# 1. similarity: 0.7477495
# text    RT @PrisonPlanet: @PrisonPlanet https://t.co/ZUOyPkjM6K
# Name: 157907, dtype: object
# 2. similarity: 0.72010493
# text    I want one like this!!! https://t.co/vqaaZai9bY
# Name: 178729, dtype: object
# 3. similarity: 0.7081519
# text    RT @zacharyebell: Agreed! https://t.co/toEnOkZ1Uf
# Name: 131123, dtype: object
# 4. similarity: 0.692747
# text    push the button lol https://t.co/mf6UG2FbJi
# Name: 78675, dtype: object
# 5. similarity: 0.66803277
# text    #ToDoListBeforeChristmas move to Canada
# Name: 138359, dtype: object
#
# cluster 16 has 292 docs like:
#
# 1. similarity: 0.7657368
# text    lol\r\nright https://t.co/8RX22q9dux
# Name: 61455, dtype: object
# 2. similarity: 0.759788
# text    They`r too hot! http://t.co/58A5lGj4Zd
# Name: 37262, dtype: object
# 3. similarity: 0.7123573
# text    Learn to love yourself.
# Name: 84905, dtype: object
# 4. similarity: 0.7021856
# text    RT @jesusthethot: Careers. https://t.co/jXcgRb8rWh
# Name: 6397, dtype: object
# 5. similarity: 0.69451153
# text    RT @riteprices: https://t.co/V810xTEyuT https://t.co/L4acD6iIwQ
# Name: 162353, dtype: object
#
# cluster 6 has 376 docs like:
#
# 1. similarity: 0.76108927
# text    #RenameMillionWomenMarch The Psychopathic Sycophant March
# Name: 198867, dtype: object
# 2. similarity: 0.70797545
# text    RT @sachagibts: #RuinADinnerInOnePhrase @GiselleEvns https://t.co/QWuc45Zmxv
# Name: 183707, dtype: object
# 3. similarity: 0.6873134
# text    RT @GLCmom: https://t.co/GfdupW33aK @realDonaldTrump
# Name: 94899, dtype: object
# 4. similarity: 0.6867666
# text    Trump's border wall.  #ThingsInventedWhileHigh
# Name: 75876, dtype: object
# 5. similarity: 0.66902506
# text    Join the game! https://t.co/O8OhWYQP9o
# Name: 150534, dtype: object
#
#
# Algorithm SD
#
# cluster -1 has 19722 docs like:
#
# 1. similarity: 0.80089676
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 2. similarity: 0.80089676
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 3. similarity: 0.7977038
# text    To me, you are perfect!
# Name: 155521, dtype: object
# 4. similarity: 0.7926399
# text    https://t.co/ITMZj5yGZj it must hurt!
# Name: 143949, dtype: object
# 5. similarity: 0.79182166
# text    @ne14phish Nice one!
# Name: 88103, dtype: object
#
# cluster 0 has 117 docs like:
#
# 1. similarity: 0.6697789
# text    RT @Oklmofficial: ! @infinitDBF gagne son procÃ¨s contre #ChristianEstrosi https://t.co/5QqI89Vl9R https://t.co/ULOL8Srur6
# Name: 145336, dtype: object
# 2. similarity: 0.6633922
# text    RT @MiamiDolphins: TEAM.  \r\n\r\n#FinsUp https://t.co/VM6o92Wja3
# Name: 108671, dtype: object
# 3. similarity: 0.65299946
# text    RT @noelitoflow: thank you for hurting me.
# Name: 102916, dtype: object
# 4. similarity: 0.6528346
# text    RT @leeleemunster: Wonderful! https://t.co/2b2ccHEK4V
# Name: 28258, dtype: object
# 5. similarity: 0.6263375
# text    RT @cmdorsey: The girl was 14 https://t.co/qnevkzY7rg
# Name: 39472, dtype: object
#
#
# Algorithm SAG
#
# cluster 0 has 19819 docs like:
#
# 1. similarity: 0.8008839
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 2. similarity: 0.8008839
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 3. similarity: 0.7976806
# text    To me, you are perfect!
# Name: 155521, dtype: object
# 4. similarity: 0.7927287
# text    https://t.co/ITMZj5yGZj it must hurt!
# Name: 143949, dtype: object
# 5. similarity: 0.79190785
# text    @ne14phish Nice one!
# Name: 88103, dtype: object
#
# cluster 19 has 1 docs like:
#
# 1. similarity: 0.3197339
# text    RT @nine_oh: Chicago actreess Lorren Cotton @lorrencotton shares her life and love of acting in issue 2 of 9.0 Magazine https://t.co/b7ZscVâ¦
# Name: 55050, dtype: object
#
# cluster 15 has 1 docs like:
#
# 1. similarity: 0.11148532
# text    #DEMNDEBATE 127 people died in Paris and what our candidates are talking about? #DemDebate https://t.co/LVFDjZKOvD
# Name: 121680, dtype: object
#
# cluster 13 has 1 docs like:
#
# 1. similarity: 0.44301844
# text    RT @zooofgenius: This scene is dead. Let's bonce. #YonceForAllOccasions
# Name: 184777, dtype: object
#
# cluster 2 has 2 docs like:
#
# 1. similarity: 0.3250717
# text    RT @CWD3D: Pre-Meditated Evangelism, NotÂ Pre-Evangelism https://t.co/ENXPS28Ih0
# Name: 96081, dtype: object
# 2. similarity: 0.15726459
# text    #Trump will #Mauer zu #Mexiko "Mexiko wird dafÃ¼r bezahlen, sie wissen es nur noch nicht"\n\n#USA #doofeBerufe #Azubis\nhttps://t.co/dhInbIpOoc
# Name: 30641, dtype: object
#
# cluster 16 has 1 docs like:
#
# 1. similarity: 0.17701104
# text    RT @Juliet777777: BLACK LIVES MATTER HATE INTERRUPTS #DNC MOMENT OF SILENCE FOR MURDERED POLICE\nhttps://t.co/FgG7ALtpSj #crookedhillary #Clâ¦
# Name: 190945, dtype: object
#
# cluster 9 has 1 docs like:
#
# 1. similarity: 0.16062057
# text    RT @WickedTheory: "That Apple-Pen song is so funny!" #MakeMeHateYouInOnePhrase
# Name: 198825, dtype: object
#
# cluster 17 has 1 docs like:
#
# 1. similarity: 0.12585674
# text    RT @GeffGefferson1: #ShouldBeAllowedAtWork #GoldenShowers \r\n(@realDonaldTrump &amp; @Rkelly Only)\r\n@iCanHash
# Name: 72926, dtype: object
#
# cluster 11 has 1 docs like:
#
# 1. similarity: 0.16120285
# text    Ð¢ÑÐ°Ð¼Ð¿ Ð¸ ÐÐ°Ð¹Ðº ÐÐµÐ½Ñ Ð¾ÐºÐ°Ð·Ð°Ð»Ð¸ÑÑ Ð² Ð¾ÑÐ»Ð¸ÑÐ½Ð¾Ð¹ ÑÐ¾ÑÐ¼Ðµ Ð¿Ð¾ ÑÐµÐ·ÑÐ»ÑÑÐ°ÑÐ°Ð¼ Ð¼ÐµÐ´Ð¸ÑÐ¸Ð½ÑÐºÐ¾Ð³Ð¾ Ð¾Ð±ÑÐ»ÐµÐ´Ð¾Ð²Ð°Ð½Ð¸Ñ\nhttps://t.co/KQAsQaaRxB https://t.co/zYjSJTv0Mf
# Name: 58521, dtype: object
#
# cluster 14 has 1 docs like:
#
# 1. similarity: 0.20062417
# text    RT @songbirdcd: Franklin Graham Leaves GOP: Why Aren't Other Christians? https://t.co/QIXO1KLpGa via @charismamag
# Name: 150856, dtype: object
#
# cluster 12 has 1 docs like:
#
# 1. similarity: 0.2740222
# text    RT @tonygoldwyn: Donald, men don't talk about women like that. Assholes do. Here are some thoughts on what worries me about a Trumpâ¦
# Name: 186806, dtype: object
#
# cluster 18 has 1 docs like:
#
# 1. similarity: 0.14142515
# text    RT @summersstine: Hosted by POS #LindaSarsour herself https://t.co/d2xGBk8Bqe
# Name: 1111, dtype: object
#
# cluster 7 has 1 docs like:
#
# 1. similarity: 0.1510033
# text    RT @OCAmericans: LOWDOWN: Wealthy Clintons Use Trusts to Limit Estate Tax They Back! #AndThenIDroppedTheMic @realDonaldTrump https://t.co/Vâ¦
# Name: 176900, dtype: object
#
# cluster 5 has 1 docs like:
#
# 1. similarity: 0.20193432
# text    RT @American1765: #BadJudgmentIn5Words\r\n\r\nBelieving it is a tight race. https://t.co/DbHsMMKREm
# Name: 134751, dtype: object
#
# cluster 10 has 1 docs like:
#
# 1. similarity: 0.20771477
# text    RT @nine_oh: Always keep content flowing,  great content that is. Indie artist advised 101.
# Name: 7445, dtype: object
#
# cluster 8 has 1 docs like:
#
# 1. similarity: 0.17074187
# text    RT @FreestyIeRaps: So we gone sit here and act like Hillary Clinton ain't been representing Death Row Records at all 3 debates? https://t.câ¦
# Name: 49783, dtype: object
#
# cluster 6 has 1 docs like:
#
# 1. similarity: 0.15458138
# text    RT @philipaklein: More Hillary on marriage: "its primary... role during those millennia has been raising and socializing of childrenâ http:â¦
# Name: 22304, dtype: object
#
# cluster 3 has 1 docs like:
#
# 1. similarity: 0.31704047
# text    Be strong in body, clean in mind, lofty in ideals. -James Naismith
# Name: 31021, dtype: object
#
# cluster 4 has 1 docs like:
#
# 1. similarity: 0.08826912
# text    RT @JaredWyand: Robert Creamer:\n\n- Felon (Bank Fraud)\n- Incited violence at Trump rallies\n- Organized voter fraud\n- 340 visits to Wâ¦
# Name: 127656, dtype: object
#
# cluster 1 has 1 docs like:
#
# 1. similarity: 0.34681052
# text    RT @ringgoldsandra: #ToDoListBeforeChristmas Remember where i put that horrible sweater Aunt Jane gave me.
# Name: 13176, dtype: object
#
#
# Algorithm SAP
#
# cluster 506 has 30 docs like:
#
# 1. similarity: 0.65573364
# text    RT @deray: what? https://t.co/btzrkGfxSX
# Name: 171837, dtype: object
# 2. similarity: 0.61153865
# text    RT @KariDeg: Actual policies. #RejectedDebateTopics
# Name: 191598, dtype: object
# 3. similarity: 0.60819906
# text    @Politweecs dafuck happened?
# Name: 30281, dtype: object
# 4. similarity: 0.60304403
# text    RT @EpicClips: Who's pops is this? ðð https://t.co/MgxY95hG63
# Name: 147359, dtype: object
# 5. similarity: 0.5794361
# text    #iamonfire funniest banned commercials http://t.co/hl9ySFpdHM
# Name: 9117, dtype: object
#
# cluster 4640 has 2 docs like:
#
# 1. similarity: 0.5907623
# text    RT @mike4libertyCA: .@SuzanneKelleher Military overwhelmingly support Trump. Those are facts..whether you or I like it or not @ryanrusty3 @â¦
# Name: 118178, dtype: object
# 2. similarity: 0.20942286
# text    @Jenn_Abrams revives hope
# Name: 110826, dtype: object
#
# cluster 0 has 1 docs like:
#
# 1. similarity: 0.69679004
# text    RT @Chevron: CEO Watson: The #oilandgas business is one of the worldâs most high-tech industries. Read more @linkedin: https://t.co/4wMMNSqâ¦
# Name: 29469, dtype: object
#
# cluster 1 has 1 docs like:
#
# 1. similarity: 0.537145
# text    RT @camboviet: Kaylene 7yr NEEDS MEDICAL ATTENTION, PLz HELP https://t.co/gYmDYqlt46 @mcrewe96 @BamagirlSelina @miketb2058 @fat711 https://â¦
# Name: 81940, dtype: object
#
# cluster 2 has 1 docs like:
#
# 1. similarity: 0.7341514
# text    RT @Bipartisanism: Trump âVictoryâ Rally Descends Into TOTAL Chaos After Protester PROVOKES DonaldÂ (DETAILS) https://t.co/ghYq1e3X9L https:â¦
# Name: 106673, dtype: object
#
# cluster 4528 has 463 docs like:
#
# 1. similarity: 0.78971475
# text    To me, you are perfect!
# Name: 155521, dtype: object
# 2. similarity: 0.75160235
# text    "#WhatIWantForChristmasIn4Words
# Name: 153750, dtype: object
# 3. similarity: 0.74390423
# text    "The Silence of the Lamborghinis.
# Name: 115159, dtype: object
# 4. similarity: 0.74208266
# text    #GiftIdeasForPoliticians truth serum
# Name: 135239, dtype: object
# 5. similarity: 0.73711467
# text    http://t.co/N2WqYCVKKg I want one like this!
# Name: 136070, dtype: object
#
# cluster 3 has 1 docs like:
#
# 1. similarity: 0.77558583
# text    RT @famousquotenet: Everything the State says is a lie, and everything it has it has stolen. - https://t.co/T1A3wIvDgf
# Name: 33216, dtype: object
#
# cluster 7181 has 511 docs like:
#
# 1. similarity: 0.78332037
# text    #InformTheElectors\r\nof what? the results? https://t.co/A6bHHW8WJs
# Name: 165829, dtype: object
# 2. similarity: 0.7794276
# text    15 minutes!
# Name: 185989, dtype: object
# 3. similarity: 0.777384
# text    #makemusicreligious Crucify were a boy
# Name: 65175, dtype: object
# 4. similarity: 0.7728452
# text    If it is, create your own one https://t.co/Pg4rAOQIxe
# Name: 127501, dtype: object
# 5. similarity: 0.7713086
# text    #IReallyLikeYouBut u too proud #cheza_chini
# Name: 189333, dtype: object
#
# cluster 7634 has 724 docs like:
#
# 1. similarity: 0.78649366
# text    Yes! https://t.co/QMfAV24pbC
# Name: 153428, dtype: object
# 2. similarity: 0.77977556
# text    Ovi #seriously https://t.co/cq9goQVXak
# Name: 202766, dtype: object
# 3. similarity: 0.75328964
# text    @midnight"
# Name: 109945, dtype: object
# 4. similarity: 0.72816473
# text    RT @MZGunter: Hell no. https://t.co/VJbLAj20Cj
# Name: 151569, dtype: object
# 5. similarity: 0.727326
# text    RT @prezydentpl: Pierwsza Dama odwiedziÅa w poniedziaÅek Gimnazjum BeÅ¾igrad w Lublanie i poprowadziÅa lekcjÄ jÄzyka niemieckiego.\r\n\r\n&gt;&gt; httpsâ¦
# Name: 188261, dtype: object
#
# cluster 4 has 1 docs like:
#
# 1. similarity: 0.69153047
# text    RT @AziDDS97: @FoxNewsInsider @TuckerCarlson nobody seemed to care when millions like me lost our Ins because of Obamacare
# Name: 155722, dtype: object
#
# cluster 2084 has 32 docs like:
#
# 1. similarity: 0.6016045
# text    RT @Jenn_Abrams: #RejectedDebateTopics who wore it better https://t.co/fni9nffph4
# Name: 199567, dtype: object
# 2. similarity: 0.5926592
# text    RT @Mr_ItIsOurDuty: strange fruit then.\r\nstrange fruit now.\r\n#sixwordstory
# Name: 84709, dtype: object
# 3. similarity: 0.5914848
# text    #IfIHadABodyDouble I'd never ever tweet myself
# Name: 122497, dtype: object
# 4. similarity: 0.5841304
# text    RT @AnnoGalactic: Tuesday: Monday's Monday.
# Name: 177618, dtype: object
# 5. similarity: 0.5817252
# text    Muslims know no Peace \r\n#IslamIsTheProblem https://t.co/8E6AURNyU2
# Name: 26575, dtype: object
#
# cluster 203 has 136 docs like:
#
# 1. similarity: 0.7061649
# text    RT @CarolynsGeekOut: #NoConfederate ready for it. https://t.co/Nw37yYYaMA
# Name: 37255, dtype: object
# 2. similarity: 0.6532679
# text    RT @Jilly_Strachan: Pls RT. https://t.co/L8YfBZtATt
# Name: 200600, dtype: object
# 3. similarity: 0.64604616
# text    This Song #MustBeBanned https://t.co/6X8rDku0kN
# Name: 129528, dtype: object
# 4. similarity: 0.6421758
# text    RT @emenogu_phil: https://t.co/XmxDh6FpyX
# Name: 49149, dtype: object
# 5. similarity: 0.6038039
# text    RT @Trump_World: @realDonaldTrump https://t.co/2fgtBIkNSq
# Name: 143348, dtype: object
#
# cluster 5 has 1 docs like:
#
# 1. similarity: 0.7917107
# text    RT @FoxNews: .@MichaelCohen212 on @realDonaldTrump: âHeâs going to be the president that ends up working with everybody.â #Hannity https://â¦
# Name: 32849, dtype: object
#
# cluster 6 has 1 docs like:
#
# 1. similarity: 0.7150516
# text    "We should be very grateful that the Age of Obama is finally over." ~ @RevCLBryant https://t.co/7ZRHcCZhKS
# Name: 194516, dtype: object
#
# cluster 7 has 1 docs like:
#
# 1. similarity: 0.33974102
# text    RT @Suthen_boy: âï¸US Accepts 6X More illegals than All of Latin America  https://t.co/NfAVvGCGJe Thx to O
# Name: 16401, dtype: object
#
# cluster 6371 has 261 docs like:
#
# 1. similarity: 0.7429389
# text    Malcom X-Men #AddCartoonsToHistory
# Name: 148415, dtype: object
# 2. similarity: 0.7121777
# text    #My4WordNewYearsResolution J'arrete d'etre sarcastique duh Je commencerais a fumer  j'aimerai boire un coup
# Name: 164966, dtype: object
# 3. similarity: 0.71199644
# text    Who knows https://t.co/YBvzhuSZuv
# Name: 30578, dtype: object
# 4. similarity: 0.6936345
# text    RT @iLLUSiONx3eyes: https://t.co/qSZfZ8ADNx
# Name: 105819, dtype: object
# 5. similarity: 0.6899714
# text    #StonedComicBooks @midnight Apocalitse
# Name: 144256, dtype: object
#
# cluster 8 has 1 docs like:
#
# 1. similarity: 0.7339864
# text    RT @Amber_1017: #ThoughtISaw myself being productive today but I can't even
# Name: 140194, dtype: object
#
# cluster 9 has 1 docs like:
#
# 1. similarity: 0.79079294
# text    RT @Beyond_I_Do: I had little confidence in govt. Now I have 0. Cheryl Mills gets immunity in FBI probe of Clinton email server https://t.câ¦
# Name: 63449, dtype: object
#
# cluster 2726 has 8 docs like:
#
# 1. similarity: 0.5098187
# text    RT @MagentaRocks: #2016In4Words\r\n\r\nAmerica. Decorum not required.
# Name: 88863, dtype: object
# 2. similarity: 0.47804436
# text    RT @bunniboila: Hey Nessie, you're so fine!\r\nYour so fine you blow my mind...\r\nHey Nessie!\r\n#scottishsongs
# Name: 120062, dtype: object
# 3. similarity: 0.4196125
# text    RT @dixiefortrump: #WomensMarch YOU FOOLS!! ð https://t.co/vmsqit3EpY
# Name: 55582, dtype: object
# 4. similarity: 0.40141416
# text    RT @trumpamericann: QUESTION: Do You Support Trumpâs New Plan For a STRONG US Military? https://t.co/B55ZA5enji https://t.co/8W17GSKvtY
# Name: 133636, dtype: object
# 5. similarity: 0.38670275
# text    RT @FreeUlsterman: @jimmygarner @5740adams @rektifiar @TeamTrumpAZ @hemplify @sheila14all @MiceeMouse I recommend reading the #AuthorisedVeâ¦
# Name: 142604, dtype: object
#
# cluster 10 has 1 docs like:
#
# 1. similarity: 0.7156148
# text    RT @MREESE06: TUNE IN NOW! #StarInTheMorning - Weekdays (7am-10am) - @troitorain  @asktheking @apricotbunny7 @brutaltruth2682 https://t.co/â¦
# Name: 340, dtype: object
#
# cluster 11 has 1 docs like:
#
# 1. similarity: 0.75264394
# text    New ISIS is coming\r\nTake your gun! https://t.co/EpDsMzW3J5
# Name: 33121, dtype: object
#
# cluster 2280 has 213 docs like:
#
# 1. similarity: 0.7158618
# text    RT @cmdorsey: #Succubus https://t.co/kYMXzBFrah
# Name: 63010, dtype: object
# 2. similarity: 0.685691
# text    RT @SierraKilo0811: @DrMakChu Thank you for the follow!
# Name: 52250, dtype: object
# 3. similarity: 0.679829
# text    RT @ellerrehc: 742 times https://t.co/FhtUCAOu9j
# Name: 62223, dtype: object
# 4. similarity: 0.67805654
# text    #unlikelythingsheardatwalmart "Made in America"
# Name: 127780, dtype: object
# 5. similarity: 0.6717987
# text    I wish it happens more often ðð· https://t.co/lCzZa6tlJm
# Name: 196930, dtype: object
#
# cluster 12 has 1 docs like:
#
# 1. similarity: 0.7899238
# text    RT @OnlineHouston: Houston leaders fear that Fifth Ward church fire was arson  #news
# Name: 135978, dtype: object
#
# cluster 279 has 108 docs like:
#
# 1. similarity: 0.68740666
# text    Shitite Fit
# Name: 162688, dtype: object
# 2. similarity: 0.6748657
# text    RT @DavidPorkchop: You're welcome https://t.co/q6arjzbsCt
# Name: 142167, dtype: object
# 3. similarity: 0.61591315
# text    RT @crosswindlive: MT @jstines3: Dear LORD, please bless
# Name: 163830, dtype: object
# 4. similarity: 0.6052123
# text    RT @JamesMorgan92: #RealLifeMagicSpells you have money in your bank account... https://t.co/U8cqmRyPzR
# Name: 199654, dtype: object
# 5. similarity: 0.6051396
# text    #ThingsYouCantIgnore Mondays https://t.co/JnrvAnblYa
# Name: 141350, dtype: object
#
# cluster 1585 has 48 docs like:
#
# 1. similarity: 0.61189485
# text    RT @KLSouth: https://t.co/FktNZ6Ynk7
# Name: 183965, dtype: object
# 2. similarity: 0.60121745
# text    RT @riteprices: Forget unfollowers, I believe in growing. 4 new followers in the last day! Stats via https://t.co/9UJxHp7JQ3
# Name: 132603, dtype: object
# 3. similarity: 0.57565576
# text    Trump has huge support from Latinos!\nBut the media will never show this! Spread online! https://t.co/8fNIsYOEQ4
# Name: 175267, dtype: object
# 4. similarity: 0.55982363
# text    @Jenn_Abrams he is cool!
# Name: 173534, dtype: object
# 5. similarity: 0.525368
# text    I just published âSix Signs the Dictatorship Is Comingâ https://t.co/k5uCa1w6xp
# Name: 79502, dtype: object
#
# cluster 13 has 1 docs like:
#
# 1. similarity: 0.7739535
# text    Sie hat Kosovo unterstÃ¼tzt #Merkelmussbleiben
# Name: 194729, dtype: object
#
# cluster 14 has 1 docs like:
#
# 1. similarity: 0.7231638
# text    RT @Kasparov63: Russia Today is Putin's propaganda network, full of anti-US, anti-EU garbage. Perfect match! A Trump show next? https://t.câ¦
# Name: 157838, dtype: object
#
# cluster 15 has 1 docs like:
#
# 1. similarity: 0.66316605
# text    RT @MattMackowiak: He only doesn't pay the best people\n https://t.co/1XzQ13aqdQ
# Name: 110612, dtype: object
#
# cluster 16 has 1 docs like:
#
# 1. similarity: 0.72444916
# text    RT @MoneySaysItBest: are you earning extra money from using the internet? https://t.co/xD6LdyDPe6 &lt;&lt;VISIT #DPK .833
# Name: 30225, dtype: object
#
# cluster 3252 has 695 docs like:
#
# 1. similarity: 0.7750588
# text    Hey, Hillary\r\nHow are you out there? https://t.co/aXdSsHlYZX
# Name: 23414, dtype: object
# 2. similarity: 0.7408125
# text    #AddASongRuinAMovie The Witchy Woman
# Name: 186699, dtype: object
# 3. similarity: 0.7311776
# text    @LotusAmerican Yep
# Name: 199911, dtype: object
# 4. similarity: 0.71992254
# text    Rocl out bird ððð https://t.co/hrS40dcYYH
# Name: 57197, dtype: object
# 5. similarity: 0.71414447
# text    #SignsYouAreAmerican you have your own american dream
# Name: 91066, dtype: object
#
# cluster 17 has 1 docs like:
#
# 1. similarity: 0.789061
# text    RT @blicqer: â¶ Huge lake found under volcano https://t.co/xpgfJrm9rh @FoxNews https://t.co/fCGKlGf43s
# Name: 195860, dtype: object
#
# cluster 18 has 1 docs like:
#
# 1. similarity: 0.7388182
# text    RT @BIZPACReview: A Right-wing call to self defense: âWe canât always be the victims, itâs time to fight backâ https://t.co/OtsNeOcSdv httpâ¦
# Name: 179282, dtype: object
#
# cluster 19 has 1 docs like:
#
# 1. similarity: 0.7674049
# text    RT @UR_Ninja: #LibrePlanet conference starting again now at MIT (our coverage last year: https://t.co/8ZL5uYlAk6) site w stream : https://tâ¦
# Name: 163233, dtype: object
#
# cluster 20 has 1 docs like:
#
# 1. similarity: 0.734122
# text    RT @ModelInNY: @Truth_Bombers @washingtonpost @DorisTruong Looks like it's confirmed once again.@washingtonpost is filled with pigs and snaâ¦
# Name: 98198, dtype: object
#
# cluster 3179 has 210 docs like:
#
# 1. similarity: 0.7701067
# text    #IAmThankfulFor you guys @onedirection
# Name: 138780, dtype: object
# 2. similarity: 0.7645209
# text    I AM WATCHING YOU!
# Name: 186801, dtype: object
# 3. similarity: 0.7222286
# text    #ItsRiskyTo be an asshole
# Name: 72580, dtype: object
# 4. similarity: 0.7086789
# text    There's a chance for liberals\r\nhttps://t.co/g36NzEOT14
# Name: 52632, dtype: object
# 5. similarity: 0.6979485
# text    Make America Great Again  #My4WordNewYearsResolution
# Name: 34191, dtype: object
#
# cluster 2231 has 92 docs like:
#
# 1. similarity: 0.7040919
# text    You had me at Hellboy.    #OneWordOffMovieQuotes  @midnight
# Name: 2641, dtype: object
# 2. similarity: 0.6289244
# text    time to eat https://t.co/OPz025BsP5
# Name: 137885, dtype: object
# 3. similarity: 0.60503155
# text    RT @JonStall2009: #GroperInChief Bill Clinton https://t.co/ZBo9yyRvLF
# Name: 4164, dtype: object
# 4. similarity: 0.5997338
# text    RT @AntiRacismTv: I posted a new photo to Facebook https://t.co/IIPMHOolgr
# Name: 119210, dtype: object
# 5. similarity: 0.5921825
# text    RT @AnnoGalactic: #FamousCreatures\r\n\r\nNostradamouse
# Name: 103207, dtype: object
#
# cluster 7637 has 516 docs like:
#
# 1. similarity: 0.7809612
# text    #ThingsPeopleOnTwitterLike stuff....
# Name: 105987, dtype: object
# 2. similarity: 0.7634719
# text    #imvotingbecause I'm over corruption
# Name: 49915, dtype: object
# 3. similarity: 0.75774336
# text    #unlikelythingsheardatWalMart I'm with her! #hillaryclinton
# Name: 173976, dtype: object
# 4. similarity: 0.74237555
# text    https://t.co/kpwgaUrE04 yeah, man)))
# Name: 66668, dtype: object
# 5. similarity: 0.73585397
# text    If it were not for hope, the heart would break
# Name: 186594, dtype: object
#
# cluster 8239 has 36 docs like:
#
# 1. similarity: 0.68614453
# text    #MakeTVShowsAustralian Boomerang? M'Lord?
# Name: 125358, dtype: object
# 2. similarity: 0.586351
# text    RT @HensleywkAo: Don't mess with Sasquatch  #AdviceFromBigFoot https://t.co/3YhI2K9Ah8
# Name: 33231, dtype: object
# 3. similarity: 0.5520353
# text    RT @BigEnuff: #2016In4Words \r\nYou. Mine. Claimed. Forever.
# Name: 43820, dtype: object
# 4. similarity: 0.5491104
# text    RT @OhhSocialMedia: https://t.co/FabVJRp28K
# Name: 178672, dtype: object
# 5. similarity: 0.5446671
# text    RT @DanaGeezus: #UnitedStatesIn3Words This means nothing http://t.co/u5gec2aXhr
# Name: 41096, dtype: object
#
# cluster 21 has 1 docs like:
#
# 1. similarity: 0.74027586
# text    Not a single white person spent today thinking, "Oh, God, that could happen to me." https://t.co/bKq8jPtalB
# Name: 148224, dtype: object
#
# cluster 22 has 1 docs like:
#
# 1. similarity: 0.76153785
# text    RT @PennyDreadful81: Let's face it - @billmaher just wants everyone dead. First he pimps dead Trump, then dead Hillary. Who's next on his hâ¦
# Name: 110579, dtype: object
#
# cluster 3227 has 23 docs like:
#
# 1. similarity: 0.58165985
# text    RT @TalibKweli: #RIPJohnCave (far right) #whiskyboysforever https://t.co/M497Nw2yF1
# Name: 158160, dtype: object
# 2. similarity: 0.57158446
# text    #ThingsMoreTrustedThanHillary https://t.co/A3H5WWPL18 and their pro-pedophilia agenda
# Name: 35066, dtype: object
# 3. similarity: 0.56120986
# text    #ToDoListBeforeChristmas Enjoy all things and leave the rest to Santa!
# Name: 78600, dtype: object
# 4. similarity: 0.5386465
# text    How many Black women does it take to change a light bulb? https://t.co/BjFZWfOHW9
# Name: 161715, dtype: object
# 5. similarity: 0.5197723
# text    RT @andersonDrLJA: #NeverHillary an ABSOLUTE! \r\nDon't be one of those who DOESN'T CARE THAT SHE IS ... DIRTBAG! https://t.co/GoiWifItnC
# Name: 128493, dtype: object
#
# cluster 23 has 1 docs like:
#
# 1. similarity: 0.74406874
# text    RT @AmyMek: How can any Liberal look at this picture &amp; defend it? Where is the Outrage!? \r\n\r\n#BanISLAM\r\n#InternationalWomensDay https://t.co/0â¦
# Name: 60174, dtype: object
#
# cluster 24 has 1 docs like:
#
# 1. similarity: 0.79053813
# text    RT @TheStormCro: You know the #ACA is bad when their advertising ploy is "buy now, and avoid the $695 penalty." #obamaFAIL
# Name: 186983, dtype: object
#
# cluster 5268 has 19 docs like:
#
# 1. similarity: 0.569082
# text    RT @BabyJannyMeow: Nothing but W O R L D P E A C E
# Name: 127509, dtype: object
# 2. similarity: 0.5075549
# text    RT @stopbeefinradio: #NowPlaying LET EM TALK by SMOKETOWN KNAVE @Eastside_Knave on https://t.co/1jS42RnHk6
# Name: 36070, dtype: object
# 3. similarity: 0.48887008
# text    Muslim refugee âraped wife in front of toddler son for not wearing her headscarf indoorsâ #ReligionOfPeace https://t.co/1M3xkD7nOK
# Name: 193150, dtype: object
# 4. similarity: 0.47848862
# text    Liberals hate the Constitution. Sharia Law - thats okay with them https://t.co/HatjUHyElS
# Name: 102401, dtype: object
# 5. similarity: 0.4599618
# text    RT @Manekinekopro: Thanks Sayoko For Believing in Us... #TeamUP https://t.co/5Kh7EMkXvA
# Name: 61062, dtype: object
#
# cluster 25 has 1 docs like:
#
# 1. similarity: 0.7069869
# text    RT @ZaibatsuNews: White Americans are the biggest terror threat in the United States: study: https://t.co/TS6oegE7Xz #p2 #tcot #maga https:â¦
# Name: 11314, dtype: object
#
# cluster 8355 has 564 docs like:
#
# 1. similarity: 0.79003334
# text    @ne14phish Nice one!
# Name: 88103, dtype: object
# 2. similarity: 0.7756983
# text    #AddCartoonsToHistory @midnight"
# Name: 5947, dtype: object
# 3. similarity: 0.7695617
# text    @Megalodon_15 Hahaha, right!
# Name: 11915, dtype: object
# 4. similarity: 0.75894463
# text    #Economy http://t.co/akSN1ut1o4
# Name: 132374, dtype: object
# 5. similarity: 0.74797094
# text    #IHatePokemonGoBecause they keep patching my hax.
# Name: 68301, dtype: object
#
# cluster 26 has 1 docs like:
#
# 1. similarity: 0.81447524
# text    #ToAvoidWorkI make empty promises and hope that everyone will be just satisfied https://t.co/Qhdle2neky
# Name: 48419, dtype: object
#
# cluster 27 has 1 docs like:
#
# 1. similarity: 0.74150366
# text    RT @LoeningMarkus: Was ist denn der Vorschlag des @BMJV_Bund fÃ¼r 'nicht tatenlos zuschauen'? Wohlklingende Worte oder gibt es echte Initiatâ¦
# Name: 115726, dtype: object
#
# cluster 28 has 1 docs like:
#
# 1. similarity: 0.7641725
# text    #MerkelsErfolge? Ihre Hingabe den Sachen von der #EU. Ihre Treue inspiriert! Macht mich stolz
# Name: 10503, dtype: object
#
# cluster 29 has 1 docs like:
#
# 1. similarity: 0.7254096
# text    RT @Taking_Back_USA: MOLON LABE -- How the Second Amendment Guarantees America's Freedom \r\nhttps://t.co/Q4i2RSejXy 07
# Name: 100576, dtype: object
#
# cluster 30 has 1 docs like:
#
# 1. similarity: 0.57804745
# text    American children
# Name: 22382, dtype: object
#
# cluster 31 has 1 docs like:
#
# 1. similarity: 0.3546705
# text    RT @seattletimes: What's in and what's out of the latest budget proposal to emerge from Olympia lawmakers in second special session: http:/â¦
# Name: 98172, dtype: object
#
# cluster 95 has 42 docs like:
#
# 1. similarity: 0.60645235
# text    Suck what I got #MyNewCatchPhraseIs
# Name: 194644, dtype: object
# 2. similarity: 0.6021908
# text    #ICantBeUrFriendBecause you never fuck your friends
# Name: 13925, dtype: object
# 3. similarity: 0.5659068
# text    RT @TGJones_62: #RealLifeMagicSpells\r\nWhenever my wife ask me to make her a coffee I say "Poof, youre a Coffee"\r\n It never works &amp; she failsâ¦
# Name: 170583, dtype: object
# 4. similarity: 0.5409508
# text    RT @earth_universee: #GiftIdeasForPoliticians https://t.co/k97lqPdwOB
# Name: 33946, dtype: object
# 5. similarity: 0.53141683
# text    RT @girlposts: take a minute to look at Melania's face after Trump turns back around   https://t.co/UHlnedWb32
# Name: 38478, dtype: object
#
# cluster 296 has 57 docs like:
#
# 1. similarity: 0.6210799
# text    #IfIHadABodyDouble my to-do list would look like this https://t.co/EBWjqKP0So
# Name: 133097, dtype: object
# 2. similarity: 0.60821724
# text    @Cryptc_Madrigal I can't believe people can actually wear this!
# Name: 57110, dtype: object
# 3. similarity: 0.59374774
# text    RT @Aldrich420: #SupremeSacrificeDay don't forget about people who were fighting for our freedom https://t.co/JKG1Hry5DT
# Name: 119006, dtype: object
# 4. similarity: 0.58334816
# text    We support the brave men and women in uniform who serve and protect every day #LawEnforcementAppreciationday https://t.co/RZVojRXs9g
# Name: 154081, dtype: object
# 5. similarity: 0.5820928
# text    France is screwed https://t.co/24O9R4CsUD
# Name: 53292, dtype: object
#
# cluster 32 has 1 docs like:
#
# 1. similarity: 0.11001209
# text    RT @tiffsediting: https://t.co/uR84eEdIPl
# Name: 135089, dtype: object
#
# cluster 33 has 1 docs like:
#
# 1. similarity: 0.6784773
# text    #Hillary promotes sinkholes https://t.co/b5gYGRcEkP
# Name: 68737, dtype: object
#
# cluster 4179 has 77 docs like:
#
# 1. similarity: 0.6241722
# text    Business before pleasure
# Name: 137190, dtype: object
# 2. similarity: 0.60703856
# text    @SmashCanNoKicky Every Trump supporter should sign this petitionð
# Name: 27123, dtype: object
# 3. similarity: 0.6030339
# text    RT @MrVladimirPutin: @PrisonPlanet because we give them free shit
# Name: 170076, dtype: object
# 4. similarity: 0.6010544
# text    True and must see video! http://t.co/qAwOwNCRgC
# Name: 92249, dtype: object
# 5. similarity: 0.594101
# text    If you can do your job great, you get Oscar. #OscarHasNoColor #Oscars
# Name: 39224, dtype: object
#
# cluster 1650 has 3 docs like:
#
# 1. similarity: 0.68069184
# text    RT @ThielsChristian: EU urges Russia to free detained protesters https://t.co/epkFmCHBS9 â¦ #RussiaProtests @dwnews https://t.co/Bvh4U4mrvq
# Name: 99817, dtype: object
# 2. similarity: 0.38047323
# text    Strategist Karl Rove: âI Donât Seeâ Donald Trump Winning  #politics
# Name: 36232, dtype: object
# 3. similarity: 0.35924575
# text    Confederate Flags of Our Fathers #RedneckAMovie @midnight
# Name: 4685, dtype: object
#
# cluster 34 has 1 docs like:
#
# 1. similarity: 0.7639643
# text    RT @SmallBiz4Trump: .@FBI Director Comey is a snake - he was told what to do by the DOJ .. predict this will ENRAGE GOP &amp; Independent voterâ¦
# Name: 181862, dtype: object
#
# cluster 6488 has 130 docs like:
#
# 1. similarity: 0.76433104
# text    sometimes https://t.co/xVZtBdzfO3
# Name: 177187, dtype: object
# 2. similarity: 0.67682755
# text    RT @Oklmofficial: ! @infinitDBF gagne son procÃ¨s contre #ChristianEstrosi https://t.co/5QqI89Vl9R https://t.co/ULOL8Srur6
# Name: 145336, dtype: object
# 3. similarity: 0.6696628
# text    RT @MiamiDolphins: TEAM.  \r\n\r\n#FinsUp https://t.co/VM6o92Wja3
# Name: 108671, dtype: object
# 4. similarity: 0.65802616
# text    RT @leeleemunster: Wonderful! https://t.co/2b2ccHEK4V
# Name: 28258, dtype: object
# 5. similarity: 0.6543711
# text    RT @noelitoflow: thank you for hurting me.
# Name: 102916, dtype: object
#
# cluster 35 has 1 docs like:
#
# 1. similarity: 0.7594616
# text    RT @DCClothesline: Why The Melted Fuel Under Fukushima Could Poison Our Planet With Nuclear Radiation For... https://t.co/8fckbIi6Ti
# Name: 79748, dtype: object
#
# cluster 1489 has 147 docs like:
#
# 1. similarity: 0.7486611
# text    #Prayer
# Name: 33314, dtype: object
# 2. similarity: 0.669936
# text    When you're all alone, by yourself, do you like you?
# Name: 5273, dtype: object
# 3. similarity: 0.6409058
# text    But Christians don't tell others to kill anyone https://t.co/gvdav7jert
# Name: 73000, dtype: object
# 4. similarity: 0.6274888
# text    Life does not stop and start at your convenience!
# Name: 179234, dtype: object
# 5. similarity: 0.6258945
# text    Lansford and Son #AthleticsTVShows
# Name: 14526, dtype: object
#
# cluster 784 has 111 docs like:
#
# 1. similarity: 0.7188949
# text    RIP #PrayersForSanBernadino  #Prayers4California
# Name: 77780, dtype: object
# 2. similarity: 0.6522791
# text    RT @CtrlSec: Targeted #ISIS accounts\r\nhttps://t.co/miptncWSI1\r\nhttps://t.co/7QEXs4Ifdp\r\nhttps://t.co/bxcdzdn1Ks\r\n#targets #iceisis #opiceisis
# Name: 61857, dtype: object
# 3. similarity: 0.6517427
# text    RT @rolandsmartin: Dagger from @patbev21! @HoustonRockets #RedNation
# Name: 61187, dtype: object
# 4. similarity: 0.6222901
# text    RT @GraveyardSister: :( https://t.co/5ytbpJilQk
# Name: 144084, dtype: object
# 5. similarity: 0.6118947
# text    Our hashtag game hosted by @Giselleevns starts in 15 minutes
# Name: 6450, dtype: object
#
# cluster 36 has 1 docs like:
#
# 1. similarity: 0.7497639
# text    Herr #Scholz, ich hoffe darauf auch! âSo etwas wird nie wieder in Hamburg passierenâ @OlafScholz https://t.co/PIVuvPgIfw
# Name: 51669, dtype: object
#
# cluster 1573 has 254 docs like:
#
# 1. similarity: 0.75083184
# text    CAUGHT WHO?? HA-HA-HA https://t.co/hJQqnxT2Hz
# Name: 54081, dtype: object
# 2. similarity: 0.70534486
# text    #My2017Resolution may 2017 be more fuck yeah than fuck this
# Name: 156859, dtype: object
# 3. similarity: 0.69558895
# text    excellent! http://t.co/R86J3zuDks
# Name: 53937, dtype: object
# 4. similarity: 0.69485337
# text    History repeats itself\r\n#HillaryForPrison2016 https://t.co/RERCwQlDgB
# Name: 1144, dtype: object
# 5. similarity: 0.6855468
# text    RT @jomas19: THE EYES HAVE IT... https://t.co/QkeJPehVmM
# Name: 92032, dtype: object
#
# cluster 6974 has 70 docs like:
#
# 1. similarity: 0.7219334
# text    Right you are! #HappyObama  http://t.co/pnAW0tSxxb
# Name: 18714, dtype: object
# 2. similarity: 0.6659373
# text    Join the game! https://t.co/FRWKYEK2Hc
# Name: 9319, dtype: object
# 3. similarity: 0.6395117
# text    RT @osPatriot: #JustToSeeYouSmile https://t.co/f5CYCX8tgl
# Name: 138886, dtype: object
# 4. similarity: 0.6220181
# text    #MakeMeHateYouInOnePhrase I haven't seen your text
# Name: 43119, dtype: object
# 5. similarity: 0.61968863
# text    "I didn't serve, I was used" #VeteransLivesMatter https://t.co/lxfvAFDAex
# Name: 138628, dtype: object
#
# cluster 1597 has 41 docs like:
#
# 1. similarity: 0.64384156
# text    And they are going to ruin our country together https://t.co/KUMXUaxZo4
# Name: 88938, dtype: object
# 2. similarity: 0.6086484
# text    #TrumpBecause .@realDonaldTrump you the best ðð
# Name: 201142, dtype: object
# 3. similarity: 0.5642998
# text    RT @CandiLand808: Yall remember when @idriselba was on the @BlackGirlNerds podcast ?? ððð me too EVERYDAY
# Name: 41838, dtype: object
# 4. similarity: 0.5621234
# text    RT @heyits_toby: #HappyBirthdayHarryTruman Fact: In 1950 Truman nearly doubled the min wage
# Name: 179976, dtype: object
# 5. similarity: 0.52925426
# text    RT @StacyBrewer18: https://t.co/EKVXC3IE1F \r\n\r\nI agree with The Judge. Nice video clip from her regarding FBImWithHer.
# Name: 32540, dtype: object
#
# cluster 7897 has 139 docs like:
#
# 1. similarity: 0.75737846
# text    They`r too hot! http://t.co/58A5lGj4Zd
# Name: 37262, dtype: object
# 2. similarity: 0.7137308
# text    #RealLifeMagicSpells Wine Glassium Refillium
# Name: 53107, dtype: object
# 3. similarity: 0.67148787
# text    #SometimesItsOkTo not achieve something
# Name: 123919, dtype: object
# 4. similarity: 0.65175426
# text    I'm in the middle of your picture
# Name: 78, dtype: object
# 5. similarity: 0.6428825
# text    RT @cocogurl86: Chocolate chocolate chocolate ð«â¤ï¸#ValentinesDayIn3Words
# Name: 20790, dtype: object
#
# cluster 37 has 1 docs like:
#
# 1. similarity: 0.032094132
# text    RT @Jarmadillos: Set your neighbors house on fire for warmth #TipsToSurviveAPowerOutage
# Name: 61684, dtype: object
#
# cluster 2590 has 54 docs like:
#
# 1. similarity: 0.71258444
# text    @POTUS_Tweets Sure
# Name: 89548, dtype: object
# 2. similarity: 0.645964
# text    Liberals as they are #LiberalLogic https://t.co/xXlCyg6gkT
# Name: 105158, dtype: object
# 3. similarity: 0.6337015
# text    extraordinary!! https://t.co/vsaPEizIEP
# Name: 36392, dtype: object
# 4. similarity: 0.6043525
# text    I'm proud to be a Patriot! \r\n#teapartynews #theteaparty #tcot #pjnet https://t.co/eIu4H97wa0
# Name: 85423, dtype: object
# 5. similarity: 0.58356
# text    RT @JussieSmollett: #Miami moments with @jurneesmollett â¤ï¸â¤ï¸â¤ï¸â¤ï¸ https://t.co/JiwomDNb9e
# Name: 106915, dtype: object
#
# cluster 3793 has 71 docs like:
#
# 1. similarity: 0.6611429
# text    This picture is only 75 years old... https://t.co/lMySPUNpOA
# Name: 177299, dtype: object
# 2. similarity: 0.6492035
# text    #ThingsPeopleOnTwitterLike bitching about not having an edit button
# Name: 195225, dtype: object
# 3. similarity: 0.6291473
# text    RT @SugarGretel: I caught lesbianism ð¤ð·â¨ð¦ð­ðð»ðð»ðð»ðâ¨ #AndThatsHowIWentViral https://t.co/lo7Z1tW1gG
# Name: 19339, dtype: object
# 4. similarity: 0.60335577
# text    I would rather eat gravel. #CancelPlansIn5Words
# Name: 76259, dtype: object
# 5. similarity: 0.60269064
# text    RT @KlaudiaKerr: What if I eat my iphone #SearchesGoogleIsAshamedOf
# Name: 120352, dtype: object
#
# cluster 4512 has 14 docs like:
#
# 1. similarity: 0.54842603
# text    @POTUS_Tweets So he fought and he won
# Name: 128764, dtype: object
# 2. similarity: 0.5158241
# text    Why should you care, what they think of you?
# Name: 100929, dtype: object
# 3. similarity: 0.51444685
# text    RT @Anthony_Trucano: #GiftIdeasForPoliticians A 1-Way ticket to Mars.
# Name: 176555, dtype: object
# 4. similarity: 0.49154776
# text    RT @im_srishabh21: Today is refund/exchange day. #ChristmasAftermath
# Name: 142883, dtype: object
# 5. similarity: 0.44032934
# text    RT @georgeduff2: #EasterIn4Words Rabbit day in America
# Name: 135989, dtype: object
#
# cluster 3550 has 224 docs like:
#
# 1. similarity: 0.7733314
# text    We wont forget âð¿âð¿ #HappyBirthdayMalcolmX https://t.co/iYFUo0JneQ
# Name: 76718, dtype: object
# 2. similarity: 0.73219734
# text    @amandadsmith1 Sorry
# Name: 25639, dtype: object
# 3. similarity: 0.7274033
# text    #ImTooOldFor PokÃ©mon Go
# Name: 92965, dtype: object
# 4. similarity: 0.703936
# text    RT @BigHomieEnt: Up for no reason!!
# Name: 178307, dtype: object
# 5. similarity: 0.6805782
# text    @Mhettu so rude
# Name: 138971, dtype: object
#
# cluster 4132 has 73 docs like:
#
# 1. similarity: 0.73208094
# text    https://t.co/x4v6kyURnl beautiful!
# Name: 157519, dtype: object
# 2. similarity: 0.71826273
# text    @Jenn_Abrams Ha ha!
# Name: 117512, dtype: object
# 3. similarity: 0.67489684
# text    He's Building #TheWall ... https://t.co/WQ4BToWfR6
# Name: 140971, dtype: object
# 4. similarity: 0.6694424
# text    #UniteBlue #UniteDems #BlackTwitter  https://t.co/KX7JnXPuJg
# Name: 90378, dtype: object
# 5. similarity: 0.6663273
# text    @HillaryClinton You started #birtherism!
# Name: 18216, dtype: object
#
# cluster 3867 has 98 docs like:
#
# 1. similarity: 0.71498585
# text    #ICelebrateTrumpWith being OKAY https://t.co/iRqiXV3HtC
# Name: 154704, dtype: object
# 2. similarity: 0.70549816
# ...
# Name: 154655, dtype: object
# 2. similarity: 0.41055396
# text    RT @angelaw676: Mornin Beautiful Black People\r\npeace strength n powerð\r\n\r\nToday\r\nTomorrow\r\nAlways\r\nSTAY WOKE BLACK &amp; PROUDâ https://t.co/zZPNYf0Aâ¦
# Name: 41924, dtype: object
# 3. similarity: 0.38604322
# text    RT @helenmaryme: Donkey Kong Country 2: P. Diddy's Kong Quest\r\n\r\n #VideoGameCelebs\r\n @midnight
# Name: 148796, dtype: object
# 4. similarity: 0.34170324
# text    RT @LibertyBundle: RT : WOW! Surprise Karate Flip Kick Knockout! (Video) - Viral Sneakhttp://viralsneak.com/wow-surprise-karate-flip-kick-kâ¦
# Name: 114570, dtype: object
# 5. similarity: 0.3181313
# text    RT @theblaze: âWhy are these other guys not saying it?â: Rush Limbaugh reacts to @marcorubioâs debate performance: https://t.co/bChjNQ8Ia5
# Name: 38155, dtype: object
#
# cluster 5 has 4 docs like:
#
# 1. similarity: 0.40626103
# text    RT @trump2021: #Chelsea      enjoy @HillaryClinton  wants 650.000 more https://t.co/oR62vozsP1
# Name: 191463, dtype: object
# 2. similarity: 0.4045652
# text    Sometimes the heart sees what is invisible to the eye.
# Name: 3050, dtype: object
# 3. similarity: 0.34064734
# text    Polizei beginnt mit ZwangsrÃ¤umung von Szenelokal in NeukÃ¶lln. Zum GlÃ¼ck machen sie das nun endlich! #Linke #GrÃ¼ne\r\nhttps://t.co/UYzQPHnVFp
# Name: 187981, dtype: object
# 4. similarity: 0.33557588
# text    RT @KenRini1: All they had to do was do the right things FOR America.\r\nIllegal immigrants &amp; Islam are enemies of America &amp; the Constitutionâ¦
# Name: 100437, dtype: object
#
# cluster 14 has 5 docs like:
#
# 1. similarity: 0.38409245
# text    #ICantBeUrFriendBecause I am not convinced a 19 year old girl with a webcam wants a middle aged man, no matter how sexy you think I am
# Name: 162188, dtype: object
# 2. similarity: 0.33175695
# text    @miraclechildent @charliecalley63 Dindu nuffin' sentiments are not welcome here
# Name: 170918, dtype: object
# 3. similarity: 0.32365695
# text    RT @sippindoc: What are people thinking going to Dubai for vacation? think about it. https://t.co/kHKQUUrVnD
# Name: 30483, dtype: object
# 4. similarity: 0.30353308
# text    RT @Gamiliell: Sunday Service from June 19, 2016 https://t.co/mMSEBw75wr photo Rose @500px https://t.co/3QdisjYHb9 https://t.co/nOSQUnvG5e
# Name: 181269, dtype: object
# 5. similarity: 0.21401674
# text    Clinton campaign returns to airwaves in Virginia, Colorado, and runs ads for first time in Michigan... https://t.co/BNNDLPyBsC #politics
# Name: 180493, dtype: object
#
# cluster 18 has 6 docs like:
#
# 1. similarity: 0.47949088
# text    #2016ElectionIn3Words I've a bad feelingâ¦
# Name: 63452, dtype: object
# 2. similarity: 0.4627736
# text    Trump Plans to Bring Outreach to Black Audience in Detroit  #politics
# Name: 177899, dtype: object
# 3. similarity: 0.41475382
# text    RT @realDailyWire: Will Joe Biden Run In 2020? https://t.co/215pkuqxJq @benshapiro https://t.co/kNdeQ4QLO3
# Name: 49224, dtype: object
# 4. similarity: 0.3787666
# text    RT @LowKeySwag412: Eating healthy vs eating steak? #RejectedDebateTopics
# Name: 91204, dtype: object
# 5. similarity: 0.35947812
# text    RT @MeanProgress: .@POTUS #UnpopularPOTUS #NotMyPresident Mourning In America \r\n\r\nhttps://t.co/wueVHKiHeg
# Name: 6972, dtype: object
#
# cluster 4 has 4 docs like:
#
# 1. similarity: 0.33507243
# text    RT @ringgoldsandra: #ThingsDoneByMistake Using your credit cards instead of mine.
# Name: 93610, dtype: object
# 2. similarity: 0.31995004
# text    RT @moon_of_remorse: #IdRunForPresidentIf I could move in some Twitter friends into the White House with me. At least it wouldn't be too boâ¦
# Name: 172791, dtype: object
# 3. similarity: 0.31511
# text    RT @realDonaldTrump: Wow! I hear you Warren, Michigan. Streaming live - join us America. It is time to DRAIN THE SWAMP!\r\nWatch: https://t.coâ¦
# Name: 80981, dtype: object
# 4. similarity: 0.2430053
# text    RT @Michael2014abc: @joshforprogress @PoliticsPeach @MorrisBoyd @Phil_Lewis_ The DNC is giving Christmas gifts and once again black peopleâ¦
# Name: 46492, dtype: object
#
# cluster 0 has 4 docs like:
#
# 1. similarity: 0.49809736
# text    RT @cmdorsey: The girl was 14 https://t.co/qnevkzY7rg
# Name: 39472, dtype: object
# 2. similarity: 0.3722819
# text    The Latest: McMullin calls for new 'conservative movement' https://t.co/2BrV9lFW6c
# Name: 179567, dtype: object
# 3. similarity: 0.36688894
# text    RT @Pastor_Robert77: https://t.co/2my3vST7lU
# Name: 110961, dtype: object
# 4. similarity: 0.332996
# text    RT @KathieMrr: My #SurvivalGuideToThanksgiving is pass out Armageddon scenario survival booklet during meal
# Name: 80432, dtype: object
#
# cluster 3 has 3 docs like:
#
# 1. similarity: 0.25407737
# text    RT @DCClothesline: Man Destroys Corrupt City In Bulldozer Rampage: âWhat Happens When You Have Too Muchâ¦ https://t.co/UqRCZXtfjs https://t.â¦
# Name: 168277, dtype: object
# 2. similarity: 0.15578529
# text    @skipandpete Hahaha, you're calling Milo a Nazi! The MSM is broadcasting this bullshit agenda directly in your brain, isn't it?
# Name: 10135, dtype: object
# 3. similarity: 0.1255212
# text    RT @shortwave8669: If you read kook news sites, watch kook news shows, and only talk to kooks who agree...you are a kook\n#NeverTrump
# Name: 139831, dtype: object
#
#
# Algorithm NKN
#
# cluster 14 has 955 docs like:
#
# 1. similarity: 0.74895036
# text    RT @_bajan_: Exactly ! https://t.co/o4eAvHCJeG
# Name: 47926, dtype: object
# 2. similarity: 0.73916453
# text    #SometimesItsOkTo be veganâ¦ ah, no! That's never OK
# Name: 128729, dtype: object
# 3. similarity: 0.7294314
# text    They don't think at all https://t.co/ys0zdGHYIG
# Name: 126402, dtype: object
# 4. similarity: 0.72698396
# text    Rocl out bird ððð https://t.co/hrS40dcYYH
# Name: 57197, dtype: object
# 5. similarity: 0.71893346
# text    He's Building #TheWall ... https://t.co/WQ4BToWfR6
# Name: 140971, dtype: object
#
# cluster 5 has 1087 docs like:
#
# 1. similarity: 0.7915183
# text    @POTUS_Tweets Sure
# Name: 89548, dtype: object
# 2. similarity: 0.7818728
# text    The Full Housemartins  #AddABandToATVShow
# Name: 37203, dtype: object
# 3. similarity: 0.7745749
# text    Hey, Hillary\r\nHow are you out there? https://t.co/aXdSsHlYZX
# Name: 23414, dtype: object
# 4. similarity: 0.77251476
# text    Happy #InternationalWomensDay https://t.co/HvxEHNKClb
# Name: 193071, dtype: object
# 5. similarity: 0.7467237
# text    "#WhatIWantForChristmasIn4Words
# Name: 153750, dtype: object
#
# cluster 18 has 910 docs like:
#
# 1. similarity: 0.7970382
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 2. similarity: 0.76571965
# text    CAUGHT WHO?? HA-HA-HA https://t.co/hJQqnxT2Hz
# Name: 54081, dtype: object
# 3. similarity: 0.7647002
# text    sometimes https://t.co/xVZtBdzfO3
# Name: 177187, dtype: object
# 4. similarity: 0.7547649
# text    Queerious George #ProblematicKidsShows
# Name: 98610, dtype: object
# 5. similarity: 0.7489112
# text    #StickTogether and #VoteTrump https://t.co/vLeWq3EJw8 #TrumpForPresident
# Name: 166411, dtype: object
#
# cluster 11 has 835 docs like:
#
# 1. similarity: 0.7898087
# text    To me, you are perfect!
# Name: 155521, dtype: object
# 2. similarity: 0.78671646
# text    that`s what for they like us((  https://t.co/6LbByeQjBf
# Name: 163575, dtype: object
# 3. similarity: 0.7702995
# text    Happy #InternationalWomensDay https://t.co/WPP7b07BfJ
# Name: 123364, dtype: object
# 4. similarity: 0.7688058
# text    change who you are!
# Name: 78339, dtype: object
# 5. similarity: 0.76835465
# text    Happy #InternationalWomensDay https://t.co/yHxfK3yVI3
# Name: 21647, dtype: object
#
# cluster 8 has 943 docs like:
#
# 1. similarity: 0.7870507
# text    guys! Guys?? https://t.co/gZUtFmu1RI
# Name: 85628, dtype: object
# 2. similarity: 0.7693512
# text    Buy
# Name: 24313, dtype: object
# 3. similarity: 0.75766945
# text    Rape #BetterAlternativeToDebates https://t.co/lbtsvpB6qL
# Name: 79192, dtype: object
# 4. similarity: 0.7497088
# text    Who knows, who knows.. https://t.co/J2AruOej5u
# Name: 72827, dtype: object
# 5. similarity: 0.74770457
# text    #2A Hahaha, that's a good one! https://t.co/KcxqB60bMv
# Name: 122861, dtype: object
#
# cluster 9 has 1015 docs like:
#
# 1. similarity: 0.7925001
# text    @ne14phish Nice one!
# Name: 88103, dtype: object
# 2. similarity: 0.7751191
# text    They`r too hot! http://t.co/58A5lGj4Zd
# Name: 37262, dtype: object
# 3. similarity: 0.74418163
# text    @Politweecs it's beatiful
# Name: 104825, dtype: object
# 4. similarity: 0.74353576
# text    #Millennials https://t.co/Y8zSirs2co
# Name: 147719, dtype: object
# 5. similarity: 0.7418583
# text    RT @Red_velvet_2016: Yes https://t.co/aQ7On04Paq
# Name: 30991, dtype: object
#
# cluster 1 has 1355 docs like:
#
# 1. similarity: 0.79334664
# text    https://t.co/ITMZj5yGZj it must hurt!
# Name: 143949, dtype: object
# 2. similarity: 0.78498
# text    AWESOME!!! http://t.co/C8uv2LPykS
# Name: 79799, dtype: object
# 3. similarity: 0.77902305
# text    #makemusicreligious Crucify were a boy
# Name: 65175, dtype: object
# 4. similarity: 0.77783275
# text    @StaceWaters_ too many, too many ðª
# Name: 143330, dtype: object
# 5. similarity: 0.77609545
# text    If it is, create your own one https://t.co/Pg4rAOQIxe
# Name: 127501, dtype: object
#
# cluster 3 has 967 docs like:
#
# 1. similarity: 0.79428947
# text    Almost...ð #funnysports https://t.co/vuUVNAJ7fD
# Name: 20616, dtype: object
# 2. similarity: 0.78254694
# text    the chance to be the 2017 Wickerman"
# Name: 182670, dtype: object
# 3. similarity: 0.7806852
# text    Ovi #seriously https://t.co/cq9goQVXak
# Name: 202766, dtype: object
# 4. similarity: 0.7790832
# text    #OnMyBirthdayCake literally https://t.co/4vG1k4an5W
# Name: 60915, dtype: object
# 5. similarity: 0.7679521
# text    I AM WATCHING YOU!
# Name: 186801, dtype: object
#
# cluster 2 has 1034 docs like:
#
# 1. similarity: 0.7886922
# text    @ChesterCityNews she is strong!
# Name: 46052, dtype: object
# 2. similarity: 0.7713482
# text    Those lads are heroes! #DDayInMyHeart
# Name: 34958, dtype: object
# 3. similarity: 0.759306
# text    #Prayer
# Name: 33314, dtype: object
# 4. similarity: 0.75391847
# text    #TVLifeLessonsILearned  None.
# Name: 4806, dtype: object
# 5. similarity: 0.72909003
# text    #ItsRiskyTo be an asshole
# Name: 72580, dtype: object
#
# cluster 4 has 1049 docs like:
#
# 1. similarity: 0.77648336
# text    We all matter #PoliceColor
# Name: 40986, dtype: object
# 2. similarity: 0.76357937
# text    #GiftIdeasForPoliticians truth serum
# Name: 135239, dtype: object
# 3. similarity: 0.75622785
# text    #IHatePokemonGoBecause they keep patching my hax.
# Name: 68301, dtype: object
# 4. similarity: 0.7560038
# text    #WeirdDaysToRelive MONDAY
# Name: 123387, dtype: object
# 5. similarity: 0.74788994
# text    http://t.co/ZfCCgWH1uv good one!
# Name: 201299, dtype: object
#
# cluster 7 has 903 docs like:
#
# 1. similarity: 0.76721174
# text    https://t.co/x4v6kyURnl beautiful!
# Name: 157519, dtype: object
# 2. similarity: 0.76558626
# text    I feel the same! http://t.co/hVDQeAtfb6
# Name: 161016, dtype: object
# 3. similarity: 0.75363845
# text    #MyFarewellWordsWouldBe Thank you! \r\n#internationalthankyouday
# Name: 175437, dtype: object
# 4. similarity: 0.7521191
# text    What is it with their agenda
# Name: 31458, dtype: object
# 5. similarity: 0.7429863
# text    #IReallyLikeYouBut... it's not you, it's me. - Me being sick and tired of you.
# Name: 102782, dtype: object
#
# cluster 12 has 911 docs like:
#
# 1. similarity: 0.77562135
# text    lol it is very funny https://t.co/5G3vJv8Uft
# Name: 7519, dtype: object
# 2. similarity: 0.7725496
# text    Bonjour Twitter ! #monpremierTweet
# Name: 81175, dtype: object
# 3. similarity: 0.763219
# text    #GiftIdeasForPoliticians truth serum
# Name: 135239, dtype: object
# 4. similarity: 0.7381379
# text    @Politweecs yeeeeah
# Name: 130587, dtype: object
# 5. similarity: 0.72482044
# text    RT @MZGunter: Hell no. https://t.co/VJbLAj20Cj
# Name: 151569, dtype: object
#
# cluster 17 has 836 docs like:
#
# 1. similarity: 0.7790865
# text    He deserved it https://t.co/Ou3ArTHqJ8
# Name: 177015, dtype: object
# 2. similarity: 0.7760053
# text    Oh boy. #TimeTravelerProblems
# Name: 163902, dtype: object
# 3. similarity: 0.7540223
# text    I #MustBeBanned
# Name: 93950, dtype: object
# 4. similarity: 0.7520213
# text    #RenameMillionWomenMarch The Psychopathic Sycophant March
# Name: 198867, dtype: object
# 5. similarity: 0.7380529
# text    I can't stop https://t.co/XMH0M16c4v
# Name: 203351, dtype: object
#
# cluster 15 has 634 docs like:
#
# 1. similarity: 0.78479695
# text    #ReasonsIAintInARelationship I have no idea.... https://t.co/9MI00wFmCN
# Name: 183143, dtype: object
# 2. similarity: 0.7641261
# text    @midnight"
# Name: 109945, dtype: object
# 3. similarity: 0.7567004
# text    Noone believes in resling! http://t.co/2ZtwKCdRhH
# Name: 119321, dtype: object
# 4. similarity: 0.72370994
# text    In the House. in the White House #MakeAMovieHillary
# Name: 192012, dtype: object
# 5. similarity: 0.72153366
# text    RT @ameegraham: #MyFarewellWordsWouldBe\r\nBitch you thoug-
# Name: 56900, dtype: object
#
# cluster 10 has 1509 docs like:
#
# 1. similarity: 0.7871233
# text    We wont forget âð¿âð¿ #HappyBirthdayMalcolmX https://t.co/iYFUo0JneQ
# Name: 76718, dtype: object
# 2. similarity: 0.78009903
# text    That was awesome http://t.co/82bNAHF7sR
# Name: 9442, dtype: object
# 3. similarity: 0.77576673
# text    #IReallyLikeYouBut u too proud #cheza_chini
# Name: 189333, dtype: object
# 4. similarity: 0.77485216
# text    @ForkTongueRoad awesome!
# Name: 18781, dtype: object
# 5. similarity: 0.7664425
# text    #My4WordNewYearsResolution Not jinxing my resolution(s).
# Name: 21181, dtype: object
#
# cluster 6 has 1414 docs like:
#
# 1. similarity: 0.77170247
# text    sometimes https://t.co/xVZtBdzfO3
# Name: 177187, dtype: object
# 2. similarity: 0.76781553
# text    #unlikelythingsheardatWalMart I'm with her! #hillaryclinton
# Name: 173976, dtype: object
# 3. similarity: 0.7647187
# text    #Economy http://t.co/akSN1ut1o4
# Name: 132374, dtype: object
# 4. similarity: 0.7528793
# text    #MakeTVShowsAustralian Boomerang? M'Lord?
# Name: 125358, dtype: object
# 5. similarity: 0.7450104
# text    https://t.co/kpwgaUrE04 yeah, man)))
# Name: 66668, dtype: object
#
# cluster 19 has 806 docs like:
#
# 1. similarity: 0.7838507
# text    Yes! https://t.co/QMfAV24pbC
# Name: 153428, dtype: object
# 2. similarity: 0.7816254
# text    am I wrong?? lol https://t.co/ooHBOoppJW
# Name: 56985, dtype: object
# 3. similarity: 0.77210534
# text    Come break me down
# Name: 62208, dtype: object
# 4. similarity: 0.76457405
# text    @Megalodon_15 Hahaha, right!
# Name: 11915, dtype: object
# 5. similarity: 0.76122624
# text    Right you are! #HappyObama  http://t.co/pnAW0tSxxb
# Name: 18714, dtype: object
#
# cluster 13 has 1048 docs like:
#
# 1. similarity: 0.78754926
# text    #InformTheElectors\r\nof what? the results? https://t.co/A6bHHW8WJs
# Name: 165829, dtype: object
# 2. similarity: 0.7867107
# text    15 minutes!
# Name: 185989, dtype: object
# 3. similarity: 0.78328353
# text    I'll be fighting for you.
# Name: 194206, dtype: object
# 4. similarity: 0.78289676
# text    #ThingsPeopleOnTwitterLike stuff....
# Name: 105987, dtype: object
# 5. similarity: 0.77086824
# text    Dont bite your friends #RulesForEverydayLiving
# Name: 78669, dtype: object
#
# cluster 16 has 885 docs like:
#
# 1. similarity: 0.77771306
# text    Happy #InternationalWomensDay https://t.co/Nak8pXkc1j
# Name: 177461, dtype: object
# 2. similarity: 0.76687896
# text    lol\r\nright https://t.co/8RX22q9dux
# Name: 61455, dtype: object
# 3. similarity: 0.7647148
# text    @steezynun LMAOO I feel you
# Name: 180235, dtype: object
# 4. similarity: 0.7590141
# text    #SongMakesMeTearUp At Last
# Name: 22427, dtype: object
# 5. similarity: 0.7418405
# text    #IHaveARightToKnow why the house shrunks https://t.co/nwbXcucOcP
# Name: 166310, dtype: object
#
# cluster 0 has 743 docs like:
#
# 1. similarity: 0.78045845
# text    They are awesome! http://t.co/kUcRfps534
# Name: 146795, dtype: object
# 2. similarity: 0.7691145
# text    #AndThenIShouldHaveSaid BET!
# Name: 146979, dtype: object
# 3. similarity: 0.764458
# text    @Midnight  Sandshark
# Name: 75564, dtype: object
# 4. similarity: 0.75929564
# text    You had me at Hellboy.    #OneWordOffMovieQuotes  @midnight
# Name: 2641, dtype: object
# 5. similarity: 0.75687593
# text    That`s great!! http://t.co/odSIqzDSq5
# Name: 45570, dtype: object
